# %% [markdown]
# # Raw Data Processing

# %% [markdown]
# ## 1. Web crawler and flux sites htm data preprocessing
# For 2017 version of this paper builds, the resource of site information must be reliable, and only two websites are selected for web crawling: The new Fluxnet site and old Fluxnet ORNL site. In case that the wegpages are rather different,we chose Scrapy to download all the pages to local disk, and Beautifulsoup to extract information from webpages.
#
# ### 1.1 Web crawler (Scrapy) deployment

# %%
import scrapy
from scrapy.crawler import CrawlerProcess
from scrapy.utils.project import get_project_settings

class FluxSpider(scrapy.Spider):
    name = "fluxnet"
    allowed_domains = ["fluxnet.ornl.gov","fluxnet.fluxdata.org/"]
    start_urls = [
        "https://fluxnet.ornl.gov/site_list/sitename/-",
        "http://fluxnet.fluxdata.org/sites/site-list-and-pages/"
                ]

    def parse(self, response):
        filename = response.url.split("/")[-1]
        with open(filename, 'wb') as f:
            f.write(response.body)

#Initiate the Spider in Python Console
settings = get_project_settings()
process = CrawlerProcess(settings=settings)
process.crawl(FluxSpider)
process.start()
#Crawl results are regrouped into FluxNet_Old_ORNL and FLuxnet_2015Datasets

# %% [markdown]
# ### 1.2 Data extraction and cleaning using Beautifulsoup
# Beautifulsoup is quite efficient in extracting information form tabled webpages, we just inspected the source code of one page to seek for pattern, then applied this pattern to extraction codes, which would automatically deliever the values into right fields. There were two bunches of webpages coming from different sites, so we extract them seperately, and combined them together. Few 'br/'s exist in Investigators field, just define a function to delelte them. Let see how the table looks like.

# %%
from bs4 import BeautifulSoup
import pandas as pd

def Delbr(List):
    temp = List
    for line in List:
        if line == '<br/>':
            temp.remove('<br/>')
    return(temp)

#Define the positions of webpages
FluxORNLPos = 'D:/_Research/Project_Sharing_Data_FromLinux/ProjectRebuild_2017/Data/SiteInfo/FluxNet_Old_ORNL/'
FluxPos = 'D:/_Research/Project_Sharing_Data_FromLinux/ProjectRebuild_2017/Data/SiteInfo/FLuxnet_2015Datasets/'

#Old site
Fileinput = open('D:/_Research/Project_Sharing_Data_FromLinux/ProjectRebuild_2017/Data/SiteInfo/Oldfluxnet.txt')
htmllist = Fileinput.read()
htmltable = []
#Parser for extraction
for html in htmllist.split('\n')[:-1]:
    htmlmarker = open(FluxORNLPos + html)
    soup = BeautifulSoup(htmlmarker,'lxml')
    tables = soup.find_all('table') #Locate all tables
    Fluxinfo = tables[0].find_all('td')#Extract each table
    Locinfo = tables[1].find_all('td')
    Investinfo = tables[2].find_all('td')
    temp = {}
    #First td tab processing
    temp.update({'SiteName':Fluxinfo[1].contents})
    temp.update({'Description':Fluxinfo[3].contents})
    temp.update({'Status':Fluxinfo[5].contents})
    temp.update({'Code':Fluxinfo[7].contents})
    #Second
    temp.update({'Country':Locinfo[1].contents})
    temp.update({'Coordinates':Locinfo[3].contents})
    #Third
    Investors = []
    for i in range(len(Investinfo)):
        if i % 2 != 0:
            Investors.append(str(Investinfo[i]).replace('<br/>','|')[4:-5])
    temp.update({'Investigators':Investors})
    htmltable.append(temp)
Fileinput.close()

#New Site
Fileinput = open('D:/_Research/Project_Sharing_Data_FromLinux/ProjectRebuild_2017/Data/SiteInfo/Fluxnet.txt')
htmllist = Fileinput.read()
Newhtmltable = []
#Parser for extraction
for html in htmllist.split('\n')[:-1]:
    htmlmarker = open(FluxPos+ html)
    soup = BeautifulSoup(htmlmarker,'lxml')
    tables = soup.find_all('table') # Locate all tables
    Fluxinfo = tables[0].find_all('td')# Only one table left in New Files 
    temp = {}
    temp.update({'SiteName':Fluxinfo[4].contents})
    temp.update({'Code':Fluxinfo[2].contents})
    temp.update({'Coordinates':(Fluxinfo[8].contents,Fluxinfo[10].contents)})
    Investors = []
    for Inves in Fluxinfo[7].contents[0].split('">'):
        Investors.append(Inves)
    temp.update({'Investigators':Investors})
    Newhtmltable.append(temp)
Fileinput.close()

pd.DataFrame.from_dict(htmltable)
# Out:
#          Code                  Coordinates                          Country  \
# 0    [US-Dix]  [39.97122889, -74.43455028]      [New Jersey, United States]
# 1    [US-Slt]    [39.91375444, -74.595985]      [New Jersey, United States]
# 2    [US-NMj]          [46.6465, -88.5194]        [Michigan, United States]
# 3    [US-Syv]       [46.242017, -89.34765]        [Michigan, United States]
# 4    [US-NPn]  [42.31288889, -106.5571111]         [Wyoming, United States]
# 5    [US-Oho]        [41.55454, -83.84376]            [Ohio, United States]
# 6    [US-MRf]   [44.64649416, -123.551483]          [Oregon, United States]
# 7    [US-PFa]  [45.94587778, -90.27230417]       [Wisconsin, United States]
# 8    [US-Pon]  [36.76666667, -97.13333333]        [Oklahoma, United States]
# 9    [US-Upa]  [70.28147222, -148.8848333]          [Alaska, United States]
# 10   [US-Ro1]  [44.71430814, -93.08984321]       [Minnesota, United States]
# 11   [US-Ro2]  [44.72879032, -93.08885384]                  [United States]
# 12   [US-Ro3]   [44.7217122, -93.08933906]       [Minnesota, United States]
# 13   [US-Ru1]   [40.25932222, -112.478125]            [Utah, United States]
# 14   [US-Ru2]  [40.28284444, -112.4715667]            [Utah, United States]
# 15   [US-Ru3]      [40.28297222, -112.463]            [Utah, United States]
# 16   [US-SRM]       [31.82143, -110.86611]         [Arizona, United States]
# 17   [US-Smt]  [38.88997778, -76.55988333]        [Maryland, United States]
# 18   [US-Snd]         [38.0373, -121.7536]      [California, United States]
# 19   [US-Shd]  [36.93333333, -96.68333333]        [Oklahoma, United States]
# 20   [US-SO4]  [33.38444444, -116.6402611]      [California, United States]
# 21   [US-SO2]  [33.37388889, -116.6228889]      [California, United States]
# 22   [US-SO3]  [33.37719444, -116.6226944]      [California, United States]
# 23   [US-SP1]  [29.73806667, -82.21876667]         [Florida, United States]
# 24   [US-SP2]      [29.7648, -82.24481667]         [Florida, United States]
# 25   [US-SP3]  [29.75476667, -82.16328333]         [Florida, United States]
# 26   [US-SP4]     [29.80281667, -82.20315]         [Florida, United States]
# 27   [US-Ton]          [38.4316, -120.966]      [California, United States]
# 28   [US-Jss]        [30.175506, -97.8778]           [Texas, United States]
# 29   [US-UMB]        [45.55984, -84.71382]        [Michigan, United States]
# ..        ...                          ...                              ...
# 813  [US-Ra1]            [39.139, -96.523]          [Kansas, United States]
# 814  [US-Ra2]  [39.14049722, -96.52704722]          [Kansas, United States]
# 815  [US-KS1]  [28.45830448, -80.67090255]         [Florida, United States]
# 816  [US-KS2]  [28.60857739, -80.67153396]         [Florida, United States]
# 817  [US-ARM]          [36.6058, -97.4888]        [Oklahoma, United States]
# 818  [BW-Ghz]  [-22.40916667, 21.71305556]                       [Botswana]
# 819  [US-LWW]        [34.9604, -97.978895]        [Oklahoma, United States]
# 820  [US-Los]        [46.08268, -89.97919]       [Wisconsin, United States]
# 821  [US-LPH]  [42.54186111, -72.18496389]   [Massachusetts, United States]
# 822  [BW-Ma1]      [-19.9165, 23.56033333]                       [Botswana]
# 823  [US-Cub]      [39.41251389, -76.5208]        [Maryland, United States]
# 824  [US-Age]      [45.0344, -68.68203333]                  [United States]
# 825  [BW-Ma2]  [-19.60759167, 23.28693056]                       [Botswana]
# 826  [US-Ne1]      [41.165056, -96.476638]        [Nebraska, United States]
# 827  [US-Ne2]        [41.164871, -96.4701]        [Nebraska, United States]
# 828  [US-Ne3]      [41.179667, -96.439646]        [Nebraska, United States]
# 829  [US-Me1]            [44.5794, -121.5]          [Oregon, United States]
# 830  [US-Me2]         [44.4523, -121.5574]          [Oregon, United States]
# 831  [US-Me3]         [44.3154, -121.6078]          [Oregon, United States]
# 832  [US-Me4]         [44.4992, -121.6224]          [Oregon, United States]
# 833  [US-Me5]   [44.43718949, -121.566756]          [Oregon, United States]
# 834  [US-MOz]       [38.74411, -92.200009]        [Missouri, United States]
# 835  [US-MMS]       [39.32315, -86.413139]         [Indiana, United States]
# 836  [US-Ldg]  [46.95224789, -110.8852724]                  [United States]
# 837  [US-Rip]  [46.94537472, -110.8872449]                  [United States]
# 838  [US-NC1]        [35.81147, -76.71147]  [North Carolina, United States]
# 839  [US-NC2]         [35.8031, -76.66791]  [North Carolina, United States]
# 840  [US-NR1]  [40.03287778, -105.5464028]        [Colorado, United States]
# 841  [US-NR2]      [40.0325, -105.5469444]        [Colorado, United States]
# 842  [US-Ced]  [39.83794167, -74.37910111]      [New Jersey, United States]
#
#                                            Description  \
# 0    [The Fort Dix site is located in the upland fo...
# 1    [The Silas Little Experimental Forest site is ...
# 2    [The jack pine site is owned by Michigan Techn...
# 3    [The Sylvania Wilderness Area is a 8500 ha old...
# 4                                   [Subalpine/alpine]
# 5    [The Ohio Oak Openings site is located within ...
# 6    [The Marys River Fir site is part of the "Synt...
# 7    [The 447 m tall WLEF-TV television tower is lo...
# 8    [The Ponca Winter Wheat site is a 65 ha rainfe...
# 9                       [Arctic tundra:tossock tundra]
# 10   [The documented vegetation history of the G21 ...
# 11   [Rosemount- C7 is currently Active, core measu...
# 12   [Located within an exclusively agricultural la...
# 13                                  [Juniper woodland]
# 14                                         [Sagebrush]
# 15                                [Crested wheatgrass]
# 16   [The Santa Rita Experimental Range (SRER), fou...
# 17                        [Temperate deciduous forest]
# 18   [The Sherman Island site is a 38-ha peatland p...
# 19   [The Shidler Tallgrass Prairie site is located...
# 20   [The Sky Oaks New site is located near the Sky...
# 21   [Unmanaged ecosystems, regenerating after fire...
# 22   [The Sky Oaks Young site is located near the S...
# 23   [65-yr old naturally regenerated slash pine/lo...
# 24   [The Mize tract site is a regenerating clearcu...
# 25   [Pine plantation managed for pulpwood producti...
# 26   [Only active for one year, the Rayonier tract ...
# 27   [Located in the lower foothills of the Sierra ...
# 28   [The J-17 research site is part of an aquifer-...
# 29   [The UMBS site is located within a protected f...
# ..                                                 ...
# 813                     [Ungrazed and burned annually]
# 814                       [Grazed and burned annually]
# 815  [The Kennedy Space Center Slash Pine Flatwoods...
# 816  [The site is located within NASA's Kennedy Spa...
# 817  [The ARM SGP Main tower is located at the ARM ...
# 818  [The experiment was conducted on the Dqae Qare...
# 819  [Grasslands, rangeland, Temperate, continental...
# 820  [The Lost Creek flux tower is part of the Cheq...
# 821  [The site was cleared for pasture, but not dee...
# 822  [The study site is located in a savanna woodla...
# 823  [The land and fire  tower for the Baltimore-Cu...
# 824  [Argyle is currently Active, core measurements...
# 825  [This site was part of the Kalahari Transect c...
# 826  [The study site is one of three fields (all lo...
# 827  [The study site is one of three fields (all lo...
# 828  [The study site is one of three fields (all lo...
# 829  [The logging history of the stand surrounding ...
# 830  [The Metolius Intermediate Pine site is locate...
# 831  [The Metolius New Young Pine site is located i...
# 832  [The Metolius Old Pine site, located in centra...
# 833  [The Metolius First Young Pine site was locate...
# 834  [The site is located in the University of Miss...
# 835  [Owned by the Indiana Department of Natural Re...
# 836  [Lodgepole Forest is currently Active, core me...
# 837  [Riparian Meadow is currently Active, core mea...
# 838  [The North Carolina Clearcut site is located i...
# 839  [The North Carolina Loblolly Pine site is loca...
# 840  [The Niwot Ridge site is located in the Roosev...
# 841  [The Niwot Ridge site is located in a subalpin...
# 842  [The Cedar Bridge site is located in the uplan...
#
#                                          Investigators  \
# 0    [Kenneth Clark|kennethclark@fs.fed.us||USDA Fo...
# 1    [Kenneth Clark|kennethclark@fs.fed.us||USDA Fo...
# 2    [Jiquan Chen|jqchen@msu.edu||Michigan State Un...
# 3    [Ankur Desai<a href="http://flux.aos.wisc.edu/...
# 4    [William Smith<a href="http://www.wfu.edu/~smi...
# 5    [Jiquan Chen|jqchen@msu.edu||Michigan State Un...
# 6    [Beverly Law<a href="http://terraweb.forestry....
# 7    [Arlyn Andrews|arlyn.andrews@noaa.gov||NOAA ES...
# 8    [Shashi Verma<a href="http://snr.unl.edu/about...
# 9    [Walter Oechel<a href="http://www.sci.sdsu.edu...
# 10   [Timothy Griffis<a href="http://www.swac.umn.e...
# 11   [Timothy Griffis<a href="http://www.swac.umn.e...
# 12   [Timothy Griffis<a href="http://www.swac.umn.e...
# 13   [Lawrence Hipps<a href="http://psc.usu.edu/htm...
# 14   [Lawrence Hipps<a href="http://psc.usu.edu/htm...
# 15   [Lawrence Hipps<a href="http://psc.usu.edu/htm...
# 16   [Russell Scott|russ.scott@ars.usda.gov||USDA-A...
# 17   [Geoffrey Parker<a href="http://serc.si.edu/la...
# 18   [Dennis Baldocchi<a href="http://ourenvironmen...
# 19   [Shashi Verma<a href="http://snr.unl.edu/about...
# 20   [Walter Oechel<a href="http://www.sci.sdsu.edu...
# 21   [Walter Oechel<a href="http://www.sci.sdsu.edu...
# 22   [Walter Oechel<a href="http://www.sci.sdsu.edu...
# 23   [Timothy Martin<a href="http://sfrc.ufl.edu/pe...
# 24   [Timothy Martin<a href="http://sfrc.ufl.edu/pe...
# 25   [Timothy Martin<a href="http://sfrc.ufl.edu/pe...
# 26   [Timothy Martin<a href="http://sfrc.ufl.edu/pe...
# 27   [Dennis Baldocchi<a href="http://ourenvironmen...
# 28   [Marcy Litvak<a href="http://biology.unm.edu/l...
# 29   [Peter Curtis<a href="http://www.biosci.ohio-s...
# ..                                                 ...
# 813  [Jay Ham<a href="http://www.cwi.colostate.edu/...
# 814  [Jay Ham<a href="http://www.cwi.colostate.edu/...
# 815  [Bert Drake<a href="http://www.serc.si.edu/lab...
# 816  [Bert Drake<a href="http://www.serc.si.edu/lab...
# 817  [Marc Fischer<a href="http://eetd.lbl.gov/peop...
# 818  [Almut Arneth|almut.arneth@nateko.lu.se||Lund ...
# 819  [Tilden Meyers|tilden.meyers@noaa.gov||NOAA/AR...
# 820  [Ankur Desai<a href="http://flux.aos.wisc.edu/...
# 821  [Julian Hadley|jhadley@fas.harvard.edu||Harvar...
# 822  [Almut Arneth|almut.arneth@nateko.lu.se||Lund ...
# 823  [Sue Grimmond<a href="http://www.met.reading.a...
# 824  [David Hollinger|davidh@hypatia.unh.edu||USDA ...
# 825  [Almut Arneth|almut.arneth@nateko.lu.se||Lund ...
# 826  [Shashi Verma<a href="http://snr.unl.edu/about...
# 827  [Shashi Verma<a href="http://snr.unl.edu/about...
# 828  [Shashi Verma<a href="http://snr.unl.edu/about...
# 829  [Beverly Law<a href="http://terraweb.forestry....
# 830  [Beverly Law<a href="http://terraweb.forestry....
# 831  [Beverly Law<a href="http://terraweb.forestry....
# 832  [Beverly Law<a href="http://terraweb.forestry....
# 833  [Beverly Law<a href="http://terraweb.forestry....
# 834  [Lianhong Gu|lianhong-gu@ornl.gov||Oak Ridge N...
# 835  [Danilo Dragoni|ddragoni@ndep.nv.gov||Indiana ...
# 836  [Howard Epstein<a href="http://www.evsc.virgin...
# 837  [Howard Epstein<a href="http://www.evsc.virgin...
# 838  [Asko Noormets<a href="http://research.eeescie...
# 839  [Asko Noormets<a href="http://research.eeescie...
# 840  [Peter Blanken<a href="http://geography.colora...
# 841  [Dean Anderson|deander@usgs.gov||U.S. Geologic...
# 842  [Kenneth Clark|kennethclark@fs.fed.us||USDA Fo...
#
#                                            SiteName  \
# 0                                        [Fort Dix]
# 1                [Silas Little Experimental Forest]
# 2               [Northern Michigan Jack Pine Stand]
# 3                        [Sylvania Wilderness Area]
# 4                            [Northern Plains Site]
# 5                                    [Oak Openings]
# 6                          [Marys River (Fir) site]
# 7                                      [Park Falls]
# 8                                      [Ponca City]
# 9                                            [Upad]
# 10                                 [Rosemount- G21]
# 11                                  [Rosemount- C7]
# 12                                 [Rosemount- G19]
# 13                          [Juniper Woodland Site]
# 14                                 [Sagebrush Site]
# 15                        [Crested Wheatgrass Site]
# 16                            [Santa Rita Mesquite]
# 17             [Smithsonian Research Center (SERC)]
# 18                                 [Sherman Island]
# 19                                        [Shidler]
# 20                                       [Sky Oaks]
# 21                            [Sky Oaks- Old Stand]
# 22                          [Sky Oaks- Young Stand]
# 23                                    [Austin Cary]
# 24                                           [Mize]
# 25                                      [Donaldson]
# 26                                       [Rayonier]
# 27                                    [Tonzi Ranch]
# 28                              [J-17 Savanna Site]
# 29              [Univ. of Mich. Biological Station]
# ..                                              ...
# 813                     [Rannells Ranch (ungrazed)]
# 814                       [Rannells Ranch (grazed)]
# 815             [Kennedy Space Center (slash pine)]
# 816              [Kennedy Space Center (scrub oak)]
# 817                [ARM Southern Great Plains site]
# 818                    [Ghanzi/Okwa River Crossing]
# 819                      [Little Washita Watershed]
# 820                                    [Lost Creek]
# 821                          [Little Prospect Hill]
# 822                         [Maun- Mopane Woodland]
# 823                          [Cub Hill (Baltimore)]
# 824                                        [Argyle]
# 825                              [Maun- Floodplain]
# 826        [Mead - irrigated continuous maize site]
# 827  [Mead - irrigated maize-soybean rotation site]
# 828    [Mead - rainfed maize-soybean rotation site]
# 829                          [Metolius Eyerly Burn]
# 830                    [Metolius Intermediate Pine]
# 831                    [Metolius Second Young Pine]
# 832                             [Metolius Old Pine]
# 833                     [Metolius First Young Pine]
# 834                           [Missouri Ozark Site]
# 835                    [Morgan Monroe State Forest]
# 836                              [Lodgepole Forest]
# 837                               [Riparian Meadow]
# 838                       [North Carolina Clearcut]
# 839            [North Carolina Loblolly Plantation]
# 840                       [Niwot Ridge (LTER NWT1)]
# 841                       [Niwot Ridge (LTER NWT2)]
# 842                                  [Cedar Bridge]
#
#                                                 Status
# 0    [Inactive, core measurements no longer being m...
# 1     [Active, core measurements presently being made]
# 2    [Inactive, core measurements no longer being m...
# 3    [Inactive, core measurements no longer being m...
# 4    [Inactive, core measurements no longer being m...
# 5     [Active, core measurements presently being made]
# 6     [Active, core measurements presently being made]
# 7     [Active, core measurements presently being made]
# 8    [Inactive, core measurements no longer being m...
# 9    [Inactive, core measurements no longer being m...
# 10    [Active, core measurements presently being made]
# 11    [Active, core measurements presently being made]
# 12    [Active, core measurements presently being made]
# 13    [Active, core measurements presently being made]
# 14    [Active, core measurements presently being made]
# 15    [Active, core measurements presently being made]
# 16    [Active, core measurements presently being made]
# 17   [Inactive, core measurements no longer being m...
# 18    [Active, core measurements presently being made]
# 19   [Inactive, core measurements no longer being m...
# 20    [Active, core measurements presently being made]
# 21    [Active, core measurements presently being made]
# 22    [Active, core measurements presently being made]
# 23    [Active, core measurements presently being made]
# 24    [Active, core measurements presently being made]
# 25    [Active, core measurements presently being made]
# 26   [Inactive, core measurements no longer being m...
# 27    [Active, core measurements presently being made]
# 28   [Inactive, core measurements no longer being m...
# 29    [Active, core measurements presently being made]
# ..                                                 ...
# 813   [Active, core measurements presently being made]
# 814   [Active, core measurements presently being made]
# 815  [Inactive, core measurements no longer being m...
# 816  [Inactive, core measurements no longer being m...
# 817   [Active, core measurements presently being made]
# 818  [Inactive, core measurements no longer being m...
# 819  [Inactive, core measurements no longer being m...
# 820   [Active, core measurements presently being made]
# 821   [Active, core measurements presently being made]
# 822   [Active, core measurements presently being made]
# 823   [Active, core measurements presently being made]
# 824  [Inactive, core measurements no longer being m...
# 825  [Inactive, core measurements no longer being m...
# 826   [Active, core measurements presently being made]
# 827   [Active, core measurements presently being made]
# 828   [Active, core measurements presently being made]
# 829  [Inactive, core measurements no longer being m...
# 830   [Active, core measurements presently being made]
# 831  [Inactive, core measurements no longer being m...
# 832  [Inactive, core measurements no longer being m...
# 833  [Inactive, core measurements no longer being m...
# 834   [Active, core measurements presently being made]
# 835   [Active, core measurements presently being made]
# 836   [Active, core measurements presently being made]
# 837   [Active, core measurements presently being made]
# 838   [Active, core measurements presently being made]
# 839   [Active, core measurements presently being made]
# 840   [Active, core measurements presently being made]
# 841   [Active, core measurements presently being made]
# 842   [Active, core measurements presently being made]
#
# [843 rows x 7 columns]

# %% [markdown]
# Now we are almost there, the next job is to extract investigators and their respective sites, bring them together and save this information into a list. As this list is still a Site -> Investigators list, we will transform it into a Investigator -> Sites list. In case some pages didn't mentioned Investigator, we defined a Name_Exam function to drop those pages.

# %%
def Name_Exam(name):
    if ('</td>' in name) or name == '':
        return(0)
    else:
        return(1)

#Combine Investors and Sites
Site_Invest = []
for html in htmltable:
    for invest in html['Investigators']:
        Site_Invest.append([html['Code'][0],invest.split('<a')[0].split('|')[0]]) #Here <a is just the head of human page introduction

#Create Investor List and Remove Duplicate
InvestList = []
for Site in Site_Invest:
    Investor = Site[1]
    if Investor not in InvestList:
        if Name_Exam(Investor):
            InvestList.append(Investor)

InvestList = sorted(InvestList)

#Rebuld Investor >> Site List
Invest_Site = {}
for Site in Site_Invest:
    name = Site[1]
    if Invest_Site.has_key(name):
        Invest_Site[name] += ',' + Site[0] 
    else:
        Invest_Site.update({name:Site[0]})
    
Invest_Site
# Out:
# {'': u'SK-Ta1,SK-Ta2,CA-MA1,CA-MA2,CA-MA3',
#  'A. Chris Oishi': u'US-Dk1,US-Dk2,US-Dk3',
#  'Abad Chabbi': u'FR-Lus',
#  'Abel Rodrigues': u'PT-Esp',
#  'Achim Grelle': u'SE-Asa,SE-Fla,SE-Kno,SE-Sk1',
#  'Adam Wolf': u'KZ-AL1,KZ-AL2,KZ-AL3,KZ-AL4,KZ-CW1,KZ-CW2,KZ-CW3,KZ-CW4,KZ-VL1,KZ-VL2,KZ-VL3,KZ-VL4,KZ-VL5,KZ-Wht',
#  'Adrian Rocha': u'US-An1,US-An2,US-An3',
#  'Aikaterini Trepekli': u'GR-Vcs',
#  'Akira Miyata': u'JP-Mas,JP-Aka,JP-Ksa,JP-Onn,JP-Yaw',
#  'Alan Barr': u'CA-SF2,CA-SF3,CA-SJ1,CA-SJ2,CA-SJ3',
#  'Alan Knapp': u'US-Kon,US-Man,US-Ra1,US-Ra2',
#  'Alana Oakins': u'US-ICt,US-ICh,US-ICs',
#  'Albert Olioso': u'FR-Avi',
#  'Alberto Trotta': u'IT-MsN',
#  'Alejandro Castellanos': u'MX-Col',
#  'Alejandro Cueva': u'MX-EMg',
#  'Alessandra Lagomarsino': u'IT-Cng',
#  'Alessandra Vinci': u'IT-CdD,IT-Mrs',
#  'Alessandro Cescatti': u'IT-Cas,IT-La2,IT-Vig,IT-Isp,IT-SR2,IT-PT1,IT-SRo',
#  'Alessandro Matese': u'IT-Lec,IT-Pia',
#  'Alessandro Peressotti': u'IT-Be1,IT-Be2',
#  'Alessandro Zaldei': u'IT-OVr,IT-OXm,IT-Lec,IT-Pia',
#  'Alessio Boschi': u'IT-CA1,IT-CA2,IT-Ro3,IT-Ro4,IT-Ro2',
#  'Alexander Graf': u'DE-RuR,DE-RuS,DE-RuW',
#  'Alexander Knohl': u'DE-Hai,DE-Lnf,DE-Sng,DE-Sol',
#  'Alexandre Santos': u'BR-Sga',
#  'Alfonso Senatore': u'IT-MsN',
#  'Aline Jaimes': u'US-StJ',
#  'Allen Goldstein': u'US-Blo',
#  'Almut Arneth': u'BW-Mkt,BW-Ghz,BW-Ma1,BW-Ma2',
#  'Alwin Naiken': u'FR-MsS,FR-OnV',
#  'AmeriFlux': u'CA-LuM',
#  'Amnat Chidthaisong': u'TH-Rtc',
#  'Anders Lindroth': u'SE-Asa,SE-As2,SE-Fla,SE-Kno,SE-Nor,SE-Sk2,SE-St2',
#  'Andrea Pitacco': u'IT-Neg',
#  'Andreas Christen': u'CA-VSu',
#  'Andreas Ibrom': u'DK-Eng,DE-Sol,DK-Lva,DK-RCW,DK-Sor,DK-RCT,GR-Mog',
#  'Andrej Varlagin': u'RU-Fyo',
#  'Andres Schmidt': u'US-Bsg,US-Wgr,US-Wpp,US-Wwt',
#  'Andrew Kowalsky': u'ES-LgS,ES-Ln1,ES-Ln2,ES-Gdn,ES-LJu',
#  'Andrew Richardson': u'US-Bar,US-Ho1',
#  'Andrew Suyker': u'US-Ne1,US-Ne2,US-Ne3',
#  'Andr\xc3\xa9 Chanzy': u'FR-Avi',
#  'Angelo Finco': u'IT-BFt',
#  'Ankur Desai': u'US-Syv,US-PFa,US-WCr,US-Los',
#  'Anna Schoettle': u'US-GLE',
#  'Anna Tedeschi': u'IT-BCi',
#  'Annalea Lohila': u'FI-Kns,FI-Let,FI-Lom,FI-Jok,FI-Alk',
#  'Anne Griebel': u'AU-Wom',
#  'Anne Ligne': u'BE-Jal,BE-Lon,BE-Vie',
#  'Anne Ojala': u'FI-Kvr',
#  'Annual Grass Vegetation': u'CA-MA1,CA-MA2,CA-MA3',
#  'Antje Moffat': u'DE-Geb',
#  'Antonio Lara': u'CL-ACP',
#  'Antonio Manzi': u'BR-Sga',
#  'Antonio Nobre': u'BR-Ji1,BR-Ji2,BR-Ji3,BR-Ma1,BR-Ma2',
#  'Antonio Raschi': u'IT-Mal',
#  'Arina Schrier': u'NL-Re1,NL-Re2',
#  'Aristotle Liakatas': u'GR-Mog',
#  'Arjan Hensen': u'NL-Lel',
#  'Arlyn Andrews': u'US-PFa',
#  'Arnaud Carrara': u'ES-CPa,ES-LM1,ES-LM2,ES-VDA,ES-ES1,ES-ES2,ES-LMa',
#  'Arnaud Legout': u'FR-Fgs',
#  'Arti Bhatia': u'IN-IAR',
#  'Arturo Sanchez-Azofeifa': u'VE-Gan,CR-Lin,CR-Sro,MX-Cha,BR-Pan',
#  'AsiaFlux': u'IN-Bet',
#  'Asko Noormets': u'US-NC3,US-NC4,US-NC1,US-NC2',
#  'Attila Eredics': u'HU-Spr',
#  'Awad Eltahir': u'SD-Dem',
#  'Axel Don': u'DE-Meh,DE-Me2',
#  'Ayumi Kotani': u'JP-SMF',
#  'Azwitamisi Mudau': u'ZA-Kru,ZA-Map',
#  'Bai Yang': u'US-MOz',
#  'Barbara Koestner': u'DE-Tha',
#  'Barbara Marcolla': u'IT-La2,IT-VdA,IT-MBo',
#  'Barry Lesht': u'US-IB1,US-IB2',
#  'Bart Kruijt': u'BR-Ji1,BR-Ji2,BR-Ji3,BR-Ma1,BR-Ma2',
#  'Ben-Jei Tsuang': u'TW-Hui,TW-Nch',
#  'Beniamino Gioli': u'IT-CA2,IT-OXm',
#  'Benjamin Fersch': u'DE-Fen',
#  'Benjamin Fresch': u'DE-Gwg',
#  'Benjamin Loubet': u'FR-Gri',
#  'Bernard Cappelaere': u'NE-WaF,NE-WaM,NE-WaD',
#  'Bernard Heinesch': u'BE-Lon,BE-Vie',
#  'Bernard LONGDOZ': u'FR-Fgs,FR-MsS,FR-Hes',
#  'Bert Drake': u'NO-And,US-KS1,US-KS2',
#  'Bert Gielen': u'BE-Bra',
#  'Beverly Law': u'US-MRf,US-Me6,US-Bsg,US-Wgr,US-Wpp,US-Wwt,US-Me1,US-Me2,US-Me3,US-Me4,US-Me5',
#  'Bill Breiter': u'US-Ro4',
#  'Bin Zhao': u'CN-Do1,CN-Do2,CN-Do3',
#  'Bing Wang': u'CN-Dag,CN-Da2,CN-Da3',
#  'Birger Hansen': u'DK-NuF',
#  'Blandine Caquet': u'CG-Tch',
#  'Bob Evans': u'US-Ho1',
#  'Bob Scholes': u'ZA-Kru,ZA-Map',
#  'Bogdan Chojnicki': u'PL-wet',
#  'Borja Reverter': u'ES-LgS',
#  'Bradley Matthews': u'AT-Hnb',
#  'Brent Ewers': u'US-Sta,US-Wdn',
#  'Brian Amiro': u'CA-Man',
#  'Brian Andraski': u'US-ADR',
#  'Bruce Cook': u'US-Syv,US-PFa,US-WCr,US-Los',
#  'Bruce Osborne': u'IE-CLa,IE-Ca1',
#  'Bruce Wylie': u'US-Bkg',
#  'Bruno Mary': u'FR-EM1,FR-EM2',
#  'Bryan Dail': u'US-Ho1',
#  'Burkhard Beudert': u'DE-Lkb',
#  'Caesar Centeno': u'PH-RIf',
#  'CarboEurope-IP (EU-FP6)': u'SK-Ta1,SK-Ta2',
#  'Carl Bernacchi': u'US-Bo2',
#  'Carlo Calfapietra': u'IT-PCm',
#  'Carmen Emmel': u'CH-Oe2',
#  'Carol Barford': u'US-SdH',
#  'Carole Helfter': u'UK-LBT,UK-AMo,UK-EBu',
#  'Carolina Vagnoli': u'IT-OVr,IT-OXm',
#  'Caroline Vincke': u'BE-Jal,BE-Vie',
#  'Carolyn G\xc3\xb6rres': u'DK-MkA,DK-MkG,DK-MkR,DK-SkA,DK-SkG,DK-SVA,DK-SVG,DK-SVR',
#  'Carsten Gruening': u'IT-Cas,IT-Vig,IT-Isp,IT-SR2,IT-PT1,IT-SRo',
#  'Carsten Malchow': u'DE-Fen,DE-Gwg,DE-SfN,DE-RbW',
#  'Casimiro Pio': u'PT-Mi2',
#  'Cereal crop': u'CA-MA1,CA-MA2,CA-MA3',
#  'Chad Hanson': u'US-Me6,US-Bsg,US-Wgr,US-Wpp,US-Wwt,US-Me1,US-Me2,US-Me3,US-Me4,US-Me5',
#  'Changliang Shao': u'CN-Du3,CN-Du4',
#  'Charles Bourque': u'CA-Cha,CA-Na1,CA-Na2',
#  'Charles Rice': u'US-Man,US-Ra1,US-Ra2',
#  'Chelcy Miniat': u'US-Cst',
#  'Chengli Tong': u'CN-Tao',
#  'Chiara Crotti': u'AR-Lac',
#  'Chin Wong': u'AU-Jan',
#  'Chris Zou': u'US-AR1,US-AR2',
#  'Christian Bernhofer': u'DE-Gri,DE-Kli,DE-Obe,DE-Akm,DE-Spw,DE-Tha,MN-Mag',
#  'Christian Br\xc3\xbcmmer': u'DE-Bou',
#  'Christian Wille': u'RU-Sam',
#  'Christina Biasi': u'RU-Vrk',
#  'Christine Moureaux': u'BE-Dor',
#  'Christoph Ammann': u'CH-Oe1',
#  'Christoph Borel': u'US-Vca',
#  'Christoph Thomas': u'US-MRf,US-Me6,US-Me6,DE-Bay,US-Me1,US-Me2,US-Me3,US-Me5',
#  'Christoph Vogel': u'US-UMB,US-UMd',
#  'Christophe Berranger': u'FR-Lus',
#  'Christophe Chipeaux': u'FR-Bil',
#  'Christophe Flechard': u'FR-Fgs',
#  'Christophe Jourdan': u'VU-Coc',
#  'Christopher Field': u'US-Jas',
#  'Christopher Gough': u'US-UMB,US-UMd',
#  'Christopher Watts': u'MX-Ray',
#  'Christopher Williams': u'BW-GhG,BW-GhM',
#  'Chuankuan Wang': u'CN-Mao',
#  'Chunsheng Hu': u'CN-Lua',
#  'Claire Campbell': u'UK-EBu',
#  'Claudia Consalvo': u'IT-Ro2',
#  'Clemens Druee': u'DE-RuW',
#  'Clenton Owensby': u'US-KFB,US-Man,US-Ra1,US-Ra2',
#  'Colin Lloyd': u'UK-PL1,UK-PL2,UK-PL3',
#  'Constance Brown-Mitic': u'US-MtB',
#  'Corinna Rebmann': u'DE-Geb,DE-Wet,DE-GsB,DE-HoH,RU-Che,RU-Zot',
#  'Costantino Sirca': u'IT-Noe,IT-Ter',
#  'Cove Sturtevant': u'US-Tw1,US-Tw2,US-Tw3,US-Tw4',
#  'Cristina Gimeno': u'ES-CPa,ES-VDA',
#  'Cropland/Natural Vegetation Mosaic': u'CA-MA2',
#  'Croplands': u'CA-MA1,CA-MA1,CA-MA2,CA-MA3,CA-MA3',
#  'C\xc3\xa9dric Perrot': u'FR-Lus',
#  'D. Zona': u'US-Bes',
#  'Daiyu Ito': u'JP-Fsk,JP-NFT',
#  'Damiano Gianelle': u'US-UMB,IT-VdA,IT-Lav,IT-MBo',
#  'Damien Bonal': u'GF-Guy',
#  'Dan Nepstad': u'BR-Res,BR-Su1,BR-Su2',
#  'Dan Yakir': u'IL-Yat',
#  'Daniel Berveiller': u'FR-Fon',
#  'Daniel Dolfus': u'DE-RuR,DE-RuS',
#  'Daniel Rasse': u'NO-And',
#  'Daniela Famulari': u'IT-SMc,IT-BCi',
#  'Daniela Franz': u'DE-Zrk',
#  'Daniela Piscitelli': u'IT-SMc',
#  'Danilo Dragoni': u'US-MMS',
#  'Dario Papale': u'SK-Tat,IT-CA1,IT-CA2,IT-CA3,IT-Ro3,IT-Ro4,IT-To1,IT-To2,IT-Amp,IT-Cpz,IT-Ro1,IT-Ro2,IT-Tol,RU-Ha1,RU-Ha2,RU-Ha3',
#  'Dave Billesbach': u'US-NGB,US-ARM',
#  'Dave Campbell': u'NZ-Kop',
#  'David Bowling': u'US-Cop',
#  'David Clark': u'CR-Lse',
#  'David Cook': u'US-Wlr,US-IB1,US-IB2',
#  'David Durden': u'US-Akn',
#  'David Edwin Reed': u'US-Sta,US-Wdn',
#  'David Ellsworth': u'US-Dk3',
#  'David Fitzjarrald': u'BR-Sa2,US-Ha1',
#  'David Foster': u'US-Ha2,US-LPH',
#  'David Holl': u'DE-Hmm',
#  'David Hollinger': u'US-Bar,US-Ho1,US-Ho2,US-Ho3,US-Age',
#  'David Johnson': u'US-KS1,US-KS2',
#  'David Werth': u'US-Akn',
#  'Dean Anderson': u'US-SDU,US-NR2',
#  'Dean Vickers': u'US-MRf,US-Me6,US-Me1,US-Me2,US-Me3,US-Me4,US-Me5',
#  'Deborah Clark': u'CR-Lse',
#  'Denis Loustau': u'FR-Bil,FR-LBr',
#  'Dennis Baldocchi': u'US-Snd,US-Ton,US-Var,US-WBW,US-Myb,US-Tw1,US-Tw2,US-Tw3,US-Tw4',
#  'Derek Eamus': u'AU-ASM,AU-TTE',
#  'Dexin Guan': u'CN-Cha',
#  'Dfb - Snow fully humid warm summer': u'CA-MA1,CA-MA2,CA-MA3',
#  'Dianxiong Cai': u'CN-Lan,CN-Dez,CN-Luo',
#  'Domenico Palumbo': u'IT-Rut',
#  'Domenico Vitale': u'IT-Ro1',
#  'Don Bragg': u'US-Cst',
#  'Donatella Spano': u'IT-Noe,IT-Ter',
#  'Dong Wang': u'US-SuM,US-SuS,US-SuW',
#  'Eddy Moors': u'NL-Haa,NL-Lan,NL-Mol,NL-Vre,NL-Lut,NL-Dij,NL-Waa,NL-Zee,NL-Ca1,NL-Loo',
#  'Eddy Smesman': u'BE-Bra',
#  'Edoardo Cremonese': u'IT-Tor,IT-TrF',
#  'Eduardo Garc\xc3\xada': u'ES-CMb,ES-CMu,ES-Yst',
#  'Edzo Veldkamp': u'CR-Lse',
#  'Eeva-Stiina Tuittila': u'FI-Sii,FI-Skj',
#  'Eiko Nemitz': u'UK-LBT,UK-EBu',
#  'El-Madany Tarek': u'ES-LM1,ES-LM2',
#  'Eleonora Canfora': u'DK-ZaF,DE-Zrk,IT-Tor,DE-RuR,DE-RuS,DE-SfN,IT-Isp,RU-SkP,FR-Aur,BE-Bra,FR-Fon,FR-Lam,GF-Guy,SE-St1',
#  'Elisa Fleischer': u'RU-KsC,RU-KsG,RU-Uts',
#  'Elisabeth Eckart': u'DE-Fen,DE-Lkb,DE-SfN,DE-RbW',
#  'Elisabeth J\xc3\xa9r\xc3\xb4me': u'BE-Dor',
#  'Elise Pendall': u'AU-Cum,US-Sta,US-Wdn',
#  'Elmar Veenendaal': u'NL-Re1,NL-Re2,BW-Ma1',
#  'Elyn Humphreys': u'CA-Mer,CA-DL1,CA-DL2',
#  'Emanuele Pallozzi': u'IT-PCm',
#  'Enrique Sanchez-Canete': u'ES-LgS,ES-Gdn',
#  'Enrique Vivoni': u'MX-Loc',
#  'Enzo Magliulo': u'IT-Gln,IT-SMc,IT-BCi',
#  'Eric Ceschia': u'FR-Aur,FR-Lam',
#  'Eric Davidson': u'US-Ha1,US-Ho1',
#  'Eric Dufrene': u'FR-Fon',
#  'Eric Grehan': u'FR-EM1,FR-EM2',
#  'Eric Larmanou': u'DE-Zrk',
#  'Erik Velazco': u'MX-Esc',
#  'Eugenie Euskirchen': u'US-NMj,US-ICt,US-ICh,US-ICs',
#  'Eugenie Limoges': u'CH-Lae',
#  'Eun Woo Park': u'KR-Suw',
#  'Eva Caballero': u'ES-AP1,ES-AP2,ES-EBn',
#  'Eva van Gorsel': u'AU-Tum',
#  'Eyal Rotenberg': u'IL-Yat',
#  'Fabio Petrella': u'IT-LMa',
#  'Fanny Kittler': u'RU-Ch2,RU-Che',
#  'Filipe Costa e Silva': u'PT-Cor',
#  'Flavia Savi': u'IT-Cp2',
#  'Francesca Ponti': u'US-Var',
#  'Francesco Mazzenga': u'IT-Col',
#  'Francesco Sabatini': u'IT-Lec,IT-Pia',
#  'Francesco Vaccari': u'IT-Pia',
#  'Francisco L\xc3\xb3pez': u'ES-CMb,ES-CMu,ES-Yst',
#  'Francisco Poveda': u'ES-Amo,ES-Agu,ES-LJu',
#  'Franck Timouk': u'ML-AgG,ML-Kem',
#  'Franco Miglietta': u'IT-Non,IT-Pia',
#  'Francois Gastal': u'FR-Lus',
#  'Frank Anderson': u'US-Twt',
#  'Frans-Jan Parmentier': u'NO-Adv,RU-Cok',
#  'Fred Kockelbergh': u'BE-Bra',
#  'Frederic Bornet': u'FR-EM1,FR-EM2',
#  'Frederic Gay': u'TH-Cgs',
#  'Fredrik Lagergren': u'SE-Nor,SE-Sk2',
#  'Fr\xc3\xa9d\xc3\xa9ric Guibal': u'FR-FBn',
#  'G. Darrel Jenerette': u'US-Dea,US-Deu',
#  'G. Robertson': u'US-KL1,US-KL2,US-KL3,US-KM1,US-KM2,US-KM3,US-KM4',
#  'Gabriel Katul': u'US-Dk1,US-Dk2,US-Dk3,US-IB1,US-IB2',
#  'Gabriel Pita': u'PT-Esp',
#  'Gabriele Guidolotti': u'IT-PCm',
#  'Gaius Shaver': u'US-ICt,US-ICh,US-ICs,US-An1,US-An2,US-An3',
#  'Galo Carrillo-Rojas': u'EC-APr',
#  'Gary lanigan': u'IE-Ca1,IE-Ca2',
#  'Gengsheng Zhang': u'US-Akn',
#  'Geoffrey Parker': u'US-Smt',
#  'Georg Hansen': u'NO-And',
#  'Georg Wohlfahrt': u'AT-Lan,AT-Leu,AT-Neu,AT-Sch,AT-Fue,AT-Rtz',
#  'George Petropoulos': u'UK-Png',
#  'George Vourlitis': u'US-Upa,BR-Mtg,US-Brw,US-HVa',
#  'Georgianne Moore': u'CR-SoC',
#  'Georgios Xenakis': u'UK-Har',
#  'Gerard Kiely': u'IE-Dgm,IE-Dri,IE-Kil,IE-Wex',
#  'Giacomo Gerosa': u'IT-BFt',
#  'Giacomo Nicolini': u'GH-Ank',
#  'Gianfranco Rana': u'IT-Rut',
#  'Gil Bohrer': u'US-UMB,US-UMd,US-ORv,US-OWC,US-UM3',
#  'Giorgio Alberti': u'IT-Be1,IT-Be2',
#  'Giorgio Matteucci': u'IT-CA3,IT-Bon,IT-Col',
#  'Giovanni Bonafe': u'IT-SPC',
#  'Giovanni Gualtieri': u'IT-OVr',
#  'Giovanni Manca': u'IT-Vig',
#  'Giuseppe Scarascia': u'IT-Bon,IT-Col',
#  'Goncharova Olga': u'RU-Ndm',
#  'Graham Maltitz': u'ZA-Kru',
#  'Grasses/Cereal Crops': u'CA-MA1,CA-MA2,CA-MA3',
#  'Gregorio Angeles': u'MX-Ato',
#  'Gregory Starr': u'US-SP1,US-SP2,US-SP3,US-Elm,US-Esm',
#  'Gretchen Miller': u'CR-SoC',
#  'Guangsheng Zhou': u'CN-Huz',
#  'Guillaume Simioni': u'FR-FBn',
#  'Gunnar Schade': u'US-Ylw',
#  'Gyorgyi Gelybo': u'HU-He1',
#  'Han Dolman': u'NL-Hor,RU-Cok',
#  'Hank Loescher': u'CR-Lse',
#  'Hank Margolis': u'CA-Qcu,CA-Qfo,CA-Qc2',
#  'Hans Peter Schmid': u'US-UMB,US-MMS',
#  'Hans Schmid': u'DE-Fen,DE-Gwg,DE-Lkb,DE-SfN,DE-RbW',
#  'Harry Lankreijer': u'SE-Nor,SE-Sk2',
#  'Harry McCaughey': u'ON-JMW,CA-Gro,CA-SF2,CA-SF3,CA-SJ1,CA-SJ2',
#  'Heiner Kreilein': u'DE-Sng',
#  'Helene Muller-Landau': u'PA-Bar',
#  'Helmut Mayer': u'DE-Har',
#  'Henrique Duarte': u'US-Akn',
#  'Henry Gholz': u'US-SP1,US-SP2,US-SP3,US-SP4,US-Cyp',
#  'Heping Liu': u'US-Bn1,US-Bn2,US-Bn3',
#  'Heye Bogena': u'DE-RuR,DE-RuS,DE-RuW',
#  'Hiroaki Kondo': u'JP-Tak',
#  'Hiroki Ikawa': u'US-Prr',
#  'Hiroyoshi Sugiura': u'JP-Sim',
#  'Hiroyuki Ohno': u'MN-Arv',
#  'Hong-Bing Su': u'US-MMS',
#  'Housen Chu': u'US-CRT,US-WPT',
#  'Howard Epstein': u'US-Bef,US-Ldg,US-Rip',
#  'Huimin Wang': u'CN-Qia',
#  'Humberto da Rocha': u'BR-Afs,BR-Ban,BR-Euc,BR-Sa3,BR-Sp1,BR-Sp2',
#  'Hyojung Kwon': u'US-Bsg,US-Wgr,US-Wpp,US-Wwt',
#  'Ian McHugh': u'AU-Fac',
#  'Ichiro Tamagawa': u'JP-Ta2',
#  'Ignacio Goded': u'IT-Isp,IT-SR2',
#  'Isabelle Mialet-Serra': u'VU-Coc',
#  'Ivan Janssens': u'BE-Bra',
#  'Ivan Mammarella': u'FI-Hyy',
#  'J. Garatuza-Payan': u'MX-Tes',
#  'J. Gruenwald': u'DE-Gri,DE-Kli,DE-Obe,DE-Akm,DE-Spw,DE-Sch,DE-Tha',
#  'J. Pettijohn': u'US-MRf',
#  'J. William Munger': u'BR-Sa1,US-Ha1,US-Ha2,US-LPH',
#  'J.C. Randolph': u'US-MMS',
#  'Jaclyn Matthes': u'US-Myb,US-Tw1',
#  'Jakob Abermann': u'DK-NuF,DK-ZaF',
#  'James Bradford': u'US-AR1,US-AR2',
#  'James Cleverly': u'AU-ASM,AU-TTE',
#  'James Guldin': u'US-Cst',
#  'James Heilman': u'US-FR1,US-FR3',
#  'James Morison': u'UK-Ham',
#  'James Randerson': u'US-Bn1,US-Bn2,US-Bn3,US-Jas',
#  'Jan Elbers': u'NL-Haa,NL-Lan,NL-Mol,NL-Vre,NL-Lut,US-AR1,US-AR2,NL-Dij,NL-Waa,NL-Zee,NL-Ca1,NL-Loo,BR-Ji1,BR-Ji2,BR-Ji3,BR-Ma1,BR-Ma2',
#  'Jan Segers': u'BE-Lcr,BE-Bra',
#  'Janina Hommeltenberg': u'DE-Fen,DE-SfN',
#  'Janne Rinne': u'FI-Sii',
#  'Janusz Olejnik': u'PL-Brd,PL-wet',
#  'Janusz Turbiak': u'PL-Bdg',
#  'Jason Beringer': u'AU-Ade,AU-Dry,AU-Stp,AU-Wom,AU-DaP,AU-DaS,AU-Fog,AU-How,AU-Meb,AU-Rgf,AU-Rig,AU-Whr,AU-Wac',
#  'Jay Ham': u'US-Man,US-Ra1,US-Ra2',
#  'Jean-Christophe Calvet': u'FR-Mau',
#  'Jean-Christophe Domec': u'US-NC4',
#  'Jean-Marc Bonnefond': u'FR-LBr',
#  'Jean-Marc Limousin': u'FR-Pue',
#  'Jean-Marc Ourcival': u'FR-Pue',
#  'Jean-Pierre Gaudill\xc3\xa8re': u'FR-Cou',
#  'Jeff Delaroy': u'US-KFB,US-KLS',
#  'Jeff Taylor': u'US-KFB',
#  'Jeff Wood': u'US-Ro4',
#  'Jeffrey Walker': u'AU-Ync',
#  'Jeremy Smith': u'DE-Bou',
#  'Jessada Phattaralerphong': u'TH-Bue',
#  'Jesse Nippert': u'US-Kon',
#  'Jiabing  Wu': u'CN-Cha',
#  'Jiahong Li': u'US-KS1,US-KS2',
#  'Jiquan Chen': u'US-NMj,US-Oho,US-Wi1,US-Wi2,US-Wi3,US-Wi4,US-Wi5,US-Wi6,US-Wi7,US-Wi8,US-Wi9,US-Wi0,US-CRT,US-KL1,US-KL2,US-KL3,US-KM1,US-KM2,US-KM3,US-KM4,US-WPT,US-NC1,US-NC2',
#  'Jiri Dusek': u'CZ-wet',
#  'Joao Pereira': u'PT-Cor,PT-Mi1,PT-Mi3',
#  'Joe McFadden': u'US-KUO,US-KUT',
#  'Joe Verfaillie': u'US-Upa,US-Tw1,US-Tw2,US-Tw3,US-Tw4,US-Atq,US-Brw,US-HVa',
#  'Johannes Hachmann': u'NL-Hor',
#  'Johannes L\xc3\xbcers': u'NO-Blv',
#  'John Baker': u'US-Ro1,US-Ro2,US-Ro3,US-KCM,US-Ro4',
#  'John Blair': u'US-Kon,US-Man,US-Ra1,US-Ra2',
#  'John Blake': u'US-Akn',
#  'John Frank': u'US-GLE',
#  'John Grace': u'BR-Cax',
#  'John Hobbie': u'US-An1,US-An2,US-An3',
#  'John King': u'US-NC4',
#  'John Lee': u'US-Ho1',
#  'John Moncrief': u'US-SP1',
#  'John Moncrieff': u'UK-ESa,UK-Gri',
#  'John Prueger': u'US-Br1,US-Br2,US-Br3',
#  'John Tenhunen': u'DE-Ber,DE-Sch',
#  'Jon Gu\xc3\xb0mundsson': u'IS-Gun',
#  'Jon Lloyd': u'BW-Ma2',
#  'Jon McCalmont': u'UK-Png',
#  'Jonas Ard\xc3\xb6': u'SN-Dhr,SD-Dem',
#  'Jonathan Martin': u'US-MRf,US-Me6',
#  'Joon Kim': u'CN-Tbs',
#  'Jordan Barr': u'US-Skr',
#  'Jordan Goodrich': u'NZ-Kop',
#  'Jorge Curiel-Yuste': u'US-Var',
#  'Jorge Perez-Quezada': u'CL-ACP,CL-SDF,CL-SDP',
#  'Jorgene Olesen': u'DK-Fou',
#  'Jose Andrade': u'MX-Kax',
#  'Jose Fuentes': u'US-Skr',
#  'Jose Moreno': u'ES-QdM',
#  'Jose Negron': u'US-GLE',
#  'Jose da Costa': u'BR-Bra',
#  'Joseph Berry': u'US-Shd',
#  'Joseph Verfaillie': u'US-Myb',
#  'Joshua Dean': u'RU-Cok',
#  'Josue Balbuena': u'MX-Oju',
#  'Joydeep Bhattacharjee': u'US-ULM',
#  'Jo\xc3\xa3o Banza': u'PT-Mi1',
#  'Juan Armesto': u'CL-SDF,CL-SDP',
#  'Julia Boike': u'NO-Blv,RU-Sam',
#  'Julian Hadley': u'US-Ha2,US-LPH',
#  'Julie Jastrow': u'US-IB1,US-IB2',
#  'Julius Oszlanyi': u'SK-Pol',
#  'Juliya Kurbatova': u'VN-NCT,RU-Fyo',
#  'Jun Asanuma': u'MN-Khr,MN-Knt,JP-Tsu',
#  'Jung-Hoon Lee': u'KR-Ceo',
#  'Junhui Zhang': u'CN-Cha',
#  'J\xc3\xa4rvi J\xc3\xa4rveoja': u'EE-Aar,EE-Hi1,EE-Hi2,EE-Ka1,EE-Ka2,EE-Ka3,EE-Ku1,EE-Ku2,EE-Lv1,EE-Lv2,EE-Lv3,EE-Mam,EE-Pdv,EE-Ph1,EE-Ph2,EE-Rok,EE-San,EE-Vg1,EE-Vg2',
#  'J\xc3\xb6rgen Sagerfors': u'SE-Fla,SE-Kno',
#  'Kalev J\xc3\xb5giste': u'EE-Jvs',
#  'Kari Minkkinen': u'FI-Kns,FI-Let,FI-Ves',
#  'Karim Piquemal': u'FR-Pue',
#  'Karl Schneider': u'DE-Seh',
#  'Karrin Alstad': u'US-Oho',
#  'Katerina Havrankova': u'CZ-KrP',
#  'Kathrin Fuchs': u'CH-Cha',
#  'Katja Klumpp': u'FR-Lq2,FR-Lq1',
#  'Katsumi Yamanoi': u'JP-Sap',
#  'Kaycie Billmark': u'US-KCM',
#  'Keith Goulding': u'UK-Her',
#  'Ken Bible': u'US-Wrc',
#  'Kenneth Clark': u'US-Dix,US-Slt,US-Cyp,US-Ced',
#  'Kenneth Davis': u'US-PFa,US-WCr',
#  'Kent Davis': u'US-MRf',
#  'Kentaro Takagi': u'JP-Tef,JP-TEF',
#  'Kenzo Kitamura': u'JP-Kah',
#  'Kevin Black': u'IE-CLa',
#  'Kim Novick': u'US-Cst',
#  'Kim Pilegaard': u'DK-Eng,DK-Lva,DK-RCW,DK-Sor,DK-Sto,DK-Ulb,DK-RCT',
#  'Kirsten Schelde': u'DK-Fou',
#  'Klaus Larsen': u'DK-RCW',
#  'Knute Nadelhoffer': u'US-UMd',
#  'Ko Huissteden': u'NL-Hor',
#  'Ko Nakaya': u'JP-Kar',
#  'Koji Tamai': u'JP-YMS',
#  'Kristiina Regina': u'FI-Jo2,FI-Jo3,FI-Jok',
#  'Krisztina Pint\xc3\xa9r': u'HU-Bug',
#  'Krzysztof Fortuniak': u'PL-Kpt',
#  'Kurt Pregitzer': u'US-NMj',
#  'Kyaw Paw U': u'US-Wrc',
#  'Kyo-Moon Shim': u'KR-Gmj',
#  'Larry Mahrt': u'US-MRf,US-Me6,US-Me1,US-Me2,US-Me3,US-Me4,US-Me5',
#  'Lars Elsgaard': u'DK-MkA,DK-MkG,DK-MkR,DK-SkA,DK-SkG,DK-SVA,DK-SVG,DK-SVR',
#  'Lars Kutzbach': u'DE-Hmm,RU-UPo,RU-Sam',
#  'Laszlo Haszpra': u'HU-He1',
#  'Laurent Kergoat': u'ML-AgG,ML-AgS,ML-Bam,ML-Kem,BJ-Nan',
#  'Lauri Laakso': u'ZA-Wgn',
#  'Laurie Koteen': u'US-Dea,US-Deu,US-Tw1,US-Tw2,US-Tw3,US-Tw4',
#  'Lawrence Flanagan': u'CA-Let,CA-WP2,CA-WP3,CA-WP1',
#  'Lawrence Hipps': u'US-Ru1,US-Ru2,US-Ru3',
#  'Leena J\xc3\xa4rvi': u'FI-Kmp',
#  'Leif Klemedtsson': u'SE-Lnn,SE-Asa,SE-Kno',
#  'Leonardo Montagnani': u'IT-Ren',
#  'Lianhong Gu': u'US-MOz',
#  'Linda Joyce': u'US-GLE',
#  'Lindsay Hutley': u'AU-Ade,AU-Dry,AU-Stp,AU-DaP,AU-DaS,AU-How',
#  'Lindy Allsman': u'US-Dea,US-Deu',
#  'Lise Soerensen': u'DK-Sto',
#  'Lorenzo Genesio': u'IT-Lec',
#  'Lorenzo Vergni': u'IT-Mrs',
#  'Loretta Johnson': u'US-Man,US-Ra1,US-Ra2',
#  'Louis Schipper': u'NZ-Kop',
#  'Luca Belelli': u'IT-Ro3,IT-Ro4,IT-To1,IT-To2,IT-Mal,IT-Ro1,IT-Ro2,IT-Tol,NL-Hor,RU-Cok,RU-Ha1,RU-Ha2,RU-Ha3',
#  'Luca Vitale': u'IT-BCi',
#  'Luciana Pires': u'US-Akn',
#  'Luisa Molina': u'MX-Esc',
#  'Lukas H\xc3\xb6rtnagl': u'CH-Aws,CH-Cha,CH-Fru,CH-Lae,CH-Oe2,CH-Dav',
#  'Lukas Siebicke': u'DE-Hai,DE-Lnf',
#  'Lulie Melling': u'MY-Cer,MY-Mud,MY-Sbu',
#  'Lutz Merbold': u'ZM-Mon,CH-Aws,CH-Cha,CH-Fru,CH-Lae,CH-Oe2,CH-Dsc,RU-Che',
#  'M. Altaf Arain': u'CA-TP1,CA-TP2,CA-TP3,CA-TP4,CA-TPD',
#  'Ma. Alberto': u'PH-RIf,PH-RIn',
#  'Maggi Kelly': u'US-Dea,US-Deu',
#  'Magnus Lund': u'SE-Faj,DK-NuF,DK-ZaF,DK-ZaH',
#  'Mamoru Nashiki': u'JP-Nsu',
#  'Manuela Balzarolo': u'IT-Amp',
#  'Manvendra Dubey': u'US-Vca',
#  'Marc Fischer': u'US-ARb,US-ARc,US-AR1,US-AR2,US-ARM',
#  'Marcy Litvak': u'US-Jss,US-Seg,US-Ses,US-Wjs,US-Mpj,US-Vcp,US-Vcm,US-FR2',
#  'Marek Urbaniak': u'PL-Tcz',
#  'Margaret Anderson-Dunn': u'UK-EBu',
#  'Margaret Torn': u'US-ARb,US-ARc,US-NGB,US-ARM',
#  'Maria Chiesa': u'IT-BFt',
#  'Maria Sanz': u'ES-ES1,ES-ES2',
#  'Maria Sebasti\xc3\xa0': u'ES-Cst,ES-LBr,ES-PRt',
#  'Marian Pavelka': u'CZ-BK2,CZ-wet,CZ-BK1',
#  'Marianna Nardino': u'IT-Ctv',
#  'Marie Coyea': u'CA-Qcu,CA-Qfo',
#  'Marilyn Roland': u'BE-Lcr,BE-Maa,BE-Bra',
#  'Mario Espirito-Santo': u'BR-Pan',
#  'Marius Schmidt': u'DE-Seh,DE-RuR,DE-RuS',
#  'Mark Castro': u'US-SP1',
#  'Mark Heuer': u'US-Bo1',
#  'Mark Sutton': u'UK-AMo,UK-Cas,UK-EBu,UK-Pol',
#  'Marko Kaasik': u'EE-Jvs',
#  'Markus Furger': u'CH-See',
#  'Markus Reichstein': u'ES-LM1,ES-LM2',
#  'Marta Galvagno': u'IT-Tor,IT-TrF',
#  'Martin Heimann': u'RU-Zfw,RU-Zbo,RU-Tuv',
#  'Martin Wilmking': u'RU-UPo',
#  'Masahito Ueyama': u'JP-Ooz,JP-Sak',
#  'Maskazu Suzuki': u'TH-Kog,TH-Moh',
#  'Mathias Herbst': u'DE-Geb,DE-Hai,DE-Lnf,DE-Bou',
#  'Mathilde Jammet': u'SE-St1',
#  'Mats Nilsson': u'SE-Deg',
#  'Matt Schroeder': u'US-Wrc',
#  'Matteo Detto': u'PA-Bar',
#  'Matteo Sottocornola': u'IT-VdA,IT-Lav,IT-MBo',
#  'Matthew Parker': u'US-Akn',
#  'Matthew Saunders': u'IE-CLa,UG-Jin,IE-Ca1,IE-Ca2',
#  'Matthew Wilkinson': u'UK-Ham',
#  'Matthias Cuntz': u'DE-GsB,DE-HoH',
#  'Matthias Dr\xc3\xb6sler': u'DE-Sch,DE-Msr',
#  'Matthias Falk': u'US-Wrc',
#  'Matthias Goeckede': u'RU-Ch2,RU-Che',
#  'Matthias Mauder': u'DE-Fen,DE-Gwg,DE-Lkb,DE-SfN,DE-RbW',
#  'Matthias Peichl': u'SE-Deg',
#  'Matthias Zeeman': u'DE-Fen,DE-Gwg,DE-RbW',
#  'Matyshak George': u'RU-Ndm',
#  'Md.Abdul Baten': u'BD-Mym',
#  'Meelis Molder': u'SE-Nor,SE-Sk2',
#  'Megan McKay': u'US-Blo',
#  'Melanie Verlinden': u'BE-Lcr',
#  'Mette Carter': u'DK-RCW',
#  'Michael Abraha': u'US-KL1,US-KL2,US-KL3,US-KM1,US-KM2,US-KM3,US-KM4',
#  'Michael Bahn': u'AT-StA,AT-StM,AT-StP',
#  'Michael Gavazzi': u'US-NC3',
#  'Michael Liddell': u'AU-Ctr,Au-Cow,Au-Rob',
#  'Michael Moreo': u'US-ADR',
#  'Michael Novak': u'CA-Ca1,CA-Ca2',
#  'Michal Heliasz': u'SE-Htm',
#  'Michel Vennetier': u'FR-FBn',
#  'Michel Zuliani': u'IT-Be1,IT-Be2',
#  'Michele Mattioni': u'IT-PCm',
#  'Michele Meroni': u'IT-PT1',
#  'Michele Tomassucci': u'IT-CA1,IT-CA2,IT-CA3,IT-Ro3,IT-Ro4,IT-Ro2',
#  'Mika Aurela': u'FI-Ken,FI-Lom,RU-Tks,FI-Kaa,FI-Sod',
#  'Mikaell L\xc3\xb6fvenius': u'SE-Svb,SE-Deg',
#  'Mike Goulden': u'CA-NS1,CA-NS2,CA-NS3,CA-NS4,CA-NS5,CA-NS6,CA-NS7,CA-NS8,US-SCc,US-SCd,US-SCg,US-SCs,US-SCf,US-SCw,US-SJ1,US-SJ2,US-SCm,BR-Sa3',
#  'Mike Jones': u'IE-Ca1,IE-Ca2',
#  'Mike Perks': u'UK-Har',
#  'Mikhail Mastepanov': u'NO-Adv',
#  'Mikkel Tamstorf': u'DK-NuF,DK-ZaF,DK-ZaH',
#  'Ming-Hsu Li': u'TW-LHC',
#  'Ming-Hwi Yao': u'TW-Tar',
#  'Minseok Kang': u'KR-Hae,KR-Kw2,KR-Seo,KR-Har,KR-Kw1',
#  'Miquel Gonzalez-Meler': u'US-IB1,US-IB2',
#  'Mirco Migliavacca': u'IT-Tor,ES-LM1,ES-LM2,IT-PT1',
#  'Miriam Hurkuck': u'DE-Bou',
#  'Monique Carnol': u'BE-Jal',
#  'Monique Leclerc': u'US-SP3,US-Akn,US-Ho1',
#  'Na Zhang': u'CN-Xg1,CN-Xg2,CN-Jnz,CN-Pa1,CN-Pa2',
#  'Naama Raz Yaseef': u'US-NGB',
#  'Nancy Kiang': u'US-Var',
#  'Narasinha Shurpali': u'RU-Vrk',
#  'Nathalie Jarosz': u'FR-LBr',
#  'Nathaniel Brunsell': u'US-KFS,US-KFB,US-KLS,US-Kon',
#  'Nazzareno Diodato': u'IT-MPn',
#  'Nele Rogiers': u'CH-See',
#  'Nestor Fernandez': u'ES-FtD,ES-MtN',
#  'Niall Hanan': u'US-Co1,US-Co2,US-Co3',
#  'Nicola Arriga': u'BE-Lcr,IT-CA1,IT-CA2,IT-CA3,IT-Ro3,IT-Ro4,IT-To1,IT-To2,BE-Maa,BE-Bra,IT-Cpz,IT-Ro1,IT-Ro2,IT-Tol',
#  'Nicolas Delpierre': u'FR-Fon',
#  'Nicolas Mascher': u'FR-Gri',
#  'Nicole Adels': u'DE-RuR,DE-RuS',
#  'Niels Jensen': u'DK-Sto',
#  'Nigel Roulet': u'CA-Mer',
#  'Nigel Tapper': u'AU-How',
#  'Niklas Rakos': u'SE-Sto',
#  'Nina Buchmann': u'CH-Aws,CH-Cha,CH-Fru,CH-Lae,CH-Oe2,CH-Dav,PA-SPs,PA-SPn',
#  'Nithya Rajan': u'US-LGr',
#  'Nobuko Saigusa': u'JP-Tef,JP-FHK,JP-Tom',
#  'Norbert Pirk': u'NO-Adv',
#  'Norma Froelich': u'CA-Cbo',
#  'Nuria Altimir': u'ES-Cst,ES-LBr,ES-PRt',
#  'Olaf Kolle': u'DE-Geb,DE-Hai,DE-Wet,ES-LM1,ES-LM2,RU-Ch2,RU-Che',
#  'Olga Pokorska': u'IT-Isp,IT-SR2',
#  'Olivier Marloie': u'FR-FBn,FR-Avi',
#  'Olivier Roupsard': u'VU-Coc',
#  'Osamu Kawamura': u'JP-Kob',
#  'Oscar Perez-Priego': u'ES-LM1,ES-LM2',
#  'Oscar Priego': u'ES-Amo,ES-Agu,ES-LgS,ES-Pdu,ES-LJu',
#  'Osvaldo Cabral': u'BR-Sp1,BR-Sp2',
#  'Osvaldo Facini': u'IT-Ctv,IT-Non',
#  'Paolo Stefani': u'GH-Ank,IT-Amp,IT-Cpz,IT-Col,IT-Mal,IT-Ro1,IT-Ro2,IT-Tol',
#  'Pasi Kolari': u'FI-Hyy',
#  'Patricio Crespo': u'EC-APr',
#  'Patrick Crill': u'SE-Sto,SE-St1',
#  'Paul Beukes': u'ZA-Wgn',
#  'Paul Bolstad': u'US-Syv,US-WCr,US-Los',
#  'Paul Brooks': u'US-Vcp,US-Vcm',
#  'Paul Di Tommasi': u'IT-Gln,IT-BCi',
#  'Paul Hanson': u'US-WBW,US-MOz',
#  'Paul Leahy': u'IE-Dri,IE-Kil,IE-Wex',
#  'Paula Escribano': u'ES-FtD,ES-MtN',
#  'Penelope Serrano': u'ES-Ln1,ES-Pdu,ES-Gdn,ES-LJu',
#  'Per Marklund': u'SE-Sto',
#  'Per Weslien': u'SE-Lnn',
#  'Peter Bakwin': u'US-PFa',
#  'Peter Blanken': u'US-NR1,US-NR2',
#  'Peter Curtis': u'US-UMB,US-UMd',
#  'Peter Ganzlin': u'US-Ro4',
#  'Peter Kuhry': u'RU-Vrk',
#  'Peter Lafleur': u'CA-Mer,CA-DL1,CA-DL2',
#  'Peter Levy': u'UK-MoH',
#  'Peter Turner': u'US-Ro4',
#  'Phil Harris': u'ML-AgG,ML-AgS,ML-Bam,ML-Kem,NE-WaD',
#  'Philip Charlesworth': u'AU-Cas',
#  'Philip Davis': u'IE-Ca2',
#  'Pia Wohland': u'BW-Ma2',
#  'PierPaolo Zara': u'IT-Noe,IT-Ter',
#  'Pieri Philippe': u'FR-Cou',
#  'Piero Toscano': u'IT-Gln,IT-OXm,IT-SMc',
#  'Pierpaolo Duce': u'IT-Noe,IT-Ter',
#  'Pierre Cellier': u'FR-Gri',
#  'Piotr Wolski': u'BW-Ma2',
#  'Pratap Bhattacharyya': u'IN-CRR',
#  'Priwitzer Tibor': u'PL-Pol',
#  'Quiliang Zhang': u'CN-Dax',
#  'Quinn Thomas': u'US-SBC',
#  'Radek Czerny': u'CZ-BK2,CZ-wet,CZ-BK1,CZ-KrP',
#  'Radoslaw Juszczak': u'PL-Brd',
#  'Raffaele Casa': u'IT-Ro3,IT-Ro4,IT-Ro1,IT-Ro2',
#  'Raili Hansen': u'EE-Rok',
#  'Rainer Steinbrecher': u'DE-Fen,DE-Gwg,DE-Lkb,DE-SfN,DE-RbW',
#  'Ralf Staebler': u'CA-Cbo',
#  'Ram Oren': u'US-Dk1,US-Dk2,US-Dk3',
#  'Ramona Magno': u'IT-Lec,IT-Pia',
#  'Rasmus Fensholt': u'SN-Dhr',
#  'Ray Anderson': u'US-SuM,US-SuS,US-SuW',
#  'Ray Leuning': u'AU-Otw,AU-Vir',
#  'Reiner Wassmann': u'PH-RIf,PH-RIn',
#  'Reinhart Ceulemans': u'BE-Lcr,BE-Bra',
#  'Riccardo Marzuoli': u'IT-BFt',
#  'Riccardo Valentini': u'GH-Ank',
#  'Richard Coulter': u'US-Wlr',
#  'Richard Harding': u'UK-PL1,UK-PL2,UK-PL3,UK-Tad',
#  'Richard Joffre': u'FR-Pue',
#  'Richard Silberstein': u'AU-Gin',
#  'Rick Stagg': u'US-Cst',
#  'Rikie Suzuki': u'US-Prr',
#  'Robert Busey': u'US-Prr',
#  'Robert Clement': u'UK-Gri',
#  'Robert Kurzeja': u'US-Akn',
#  'Robert Parmenter': u'US-Vca',
#  'Robert Simpson': u'AU-Drg,AU-Nim',
#  'Rodrigo Vargas': u'MX-EMg,US-StJ',
#  'Rolando Celleri': u'EC-APr',
#  'Rolf Siegwolf': u'CH-See',
#  'Rommel Zulueta': u'US-Upa,MX-Lpa,US-Brw,US-HVa',
#  'Ron Teclaw': u'US-PFa',
#  'Roser Matamala': u'US-IB1,US-IB2',
#  'Ross Hinkle': u'US-KS1,US-KS2',
#  'Rossana Ferrara': u'IT-Rut',
#  'Rosvel Bracho': u'US-SP1,US-SP2,US-SP3,US-SP4,US-EML',
#  'Russ Monson': u'US-NR1',
#  'Russell Scott': u'US-SRM,US-SRG,US-Wkg,US-LSM,US-Whs',
#  'Ruth Varner': u'US-Ha1',
#  'Ryusuke Hatano': u'JP-Bre,JP-Szn',
#  'R\xc3\xa9my Soubie': u'BE-Vie',
#  'Sabina Dore': u'US-Fuf,US-Fmf,US-Fwf,US-KS2',
#  'Sabina Keller': u'CH-Aws,CH-Cha,CH-Fru,CH-Lae,CH-Oe2,CH-Dav,PA-SPs,PA-SPn',
#  'Sachinobu Ishida': u'JP-Srk',
#  'Sally Archibald': u'ZA-Kru,ZA-Map',
#  'Samuel Villarreal': u'US-StJ',
#  'Sara Jimenez': u'DE-GsB,DE-HoH',
#  'Sara Knox': u'US-Tw1,US-Tw2,US-Tw3,US-Tw4',
#  'Sara Lonardo': u'IT-Gln,IT-OVr',
#  'Sari Juutinen': u'FI-Skj',
#  'Sasha Ivans': u'US-Ru1,US-Ru2,US-Ru3',
#  'Scott Miller': u'BR-Sa3',
#  'Scott Ollinger': u'US-Bar',
#  'Scott Saleska': u'BR-Sa1',
#  'Sebastian Westermann': u'NO-Blv',
#  'Sebastian Wolf': u'PA-SPs,PA-SPn',
#  'Serena Marras': u'IT-Noe',
#  'Serge Rambal': u'FR-Pue',
#  'Sergiy Medinets': u'UA-Pet',
#  'Shashi Verma': u'US-Pon,US-Shd,US-Ne1,US-Ne2,US-Ne3',
#  'Shaun Cunningham': u'AU-Stp',
#  'Shi Peili': u'CN-Dan',
#  'Shigeyuki Ishodoya': u'JP-Tak',
#  'Shihua Lu': u'CN-Maq',
#  'Shiping Chen': u'CN-Xi2,CN-Dwu,CN-Du1,CN-Du2,CN-Ku1,CN-Ku2,CN-Xi1',
#  'Shirley A. Papuga': u'US-SRC',
#  'Shohei Murayama': u'JP-Tak',
#  'Sigrid Dengel': u'FI-Var',
#  'Silvano Fares': u'IT-Cp2',
#  'Simone Righi': u'IT-SPC',
#  'Simone Sabbatini': u'IT-CA1,IT-CA2,IT-CA3,IT-Ro3,IT-Ro4,IT-Cpz,IT-Ro2',
#  'Siyan Ma': u'US-Ton,US-Var',
#  'Sofia Cerasoli': u'PT-Cor',
#  'Sonia Wharton': u'US-Wrc,US-Dia',
#  'Spyridon Rapsomanikis': u'GR-Vcs',
#  'Stan Wullschleger': u'US-WBW,US-MOz',
#  'Stefano Minerbi': u'IT-Ren',
#  'Steffen Noe': u'EE-Jvs',
#  'Stephen Ogle': u'US-Bo1',
#  'Stephen Pallardy': u'US-MOz',
#  'Steve Oberbauer': u'US-Elm,US-Esm,CR-Lse',
#  'Steven Hastings': u'MX-Lpa',
#  'Steven Hollinger': u'US-Bo2',
#  'Steven Wofsy': u'CA-Man,BR-Sa1,US-Ha1',
#  'Sue Grimmond': u'US-Cub,US-MMS',
#  'Sumit Sharma': u'US-LGr',
#  'Susan Ustin': u'US-Wrc',
#  'Susumu Yamamoto': u'CN-Lao',
#  'Suvadip Neogi': u'IN-CRR',
#  'Svetlana Zagirova': u'RU-UPo',
#  'Syndonia Bret-Harte': u'US-ICt,US-ICh,US-ICs',
#  'S\xc3\xa9bastien Conil': u'FR-MsS,FR-OnV',
#  'S\xc3\xb8ren Petersen': u'DK-MkA,DK-MkG,DK-MkR,DK-SkA,DK-SkG,DK-SVA,DK-SVG,DK-SVR',
#  'T. (Andy) Black': u'CA-Ca1,CA-Ca2,CA-Ca3,CA-Oas,CA-Obs,CA-SF1,CA-Fen,CA-SF2,CA-SF3,CA-SJ1,CA-SJ2',
#  'Taejin Choi': u'AQ-KSe,JP-Das',
#  'Tagir Gilmanov': u'US-Bkg',
#  'Taiichi Hayashi': u'JP-Shi',
#  'Taikan Oki': u'TH-Mix',
#  'Takafumi Miyama': u'JP-YMS',
#  'Takahisa Maeda': u'ID-Buk,TH-Mae,TH-Sak',
#  'Takalani Ralivhesa': u'ZA-Kru,ZA-Map',
#  'Takashi Hirano': u'ID-Pag',
#  'Takehiko Matsumoto': u'JP-Nks',
#  'Takeshi Ohta': u'JP-MBF,JP-MMF',
#  'Tanguy Manise': u'BE-Lon,BE-Vie',
#  'Tapan Adhya': u'IN-CRR',
#  'Tarek Dadi': u'ES-AP1,ES-AP2,ES-EBn',
#  'Tarmo Virtanen': u'RU-Vrk',
#  'Tatsuro Nakaji': u'JP-Hok',
#  'Ted Hehn': u'US-Var',
#  'Ted Schuur': u'US-EML',
#  'Thom Rahn': u'US-Vca',
#  'Thomas Friborg': u'RU-Vrk,DK-Ris,SE-Sto,SE-St1',
#  'Tiana Hammer': u'ES-LM1,ES-LM2',
#  'Tilden Meyers': u'US-WBW,US-Ctn,US-SFP,US-Aud,US-Blk,US-Bo1,US-Bkg,US-CaV,US-ChR,US-FPe,US-Goo,US-LWW,US-MOz',
#  'Tim Arkebauer': u'US-SdH',
#  'Tim Griffis': u'US-Ro4',
#  'Tim Moore': u'CA-Mer',
#  'Tim Parkin': u'US-NSP,US-Br1,US-Br2,US-Br3',
#  'Timo Vesala': u'FI-Hyy',
#  'Timothy Griffis': u'US-Ro1,US-Ro2,US-Ro3,US-KCM',
#  'Timothy Martin': u'US-SP1,US-SP2,US-SP3,US-SP4',
#  'Tiphaine Tallec': u'FR-Aur,FR-Lam',
#  'Tiziano Sorgi': u'IT-Cp2',
#  'Todd Perez': u'US-Dea,US-Deu',
#  'Todd Scanlon': u'ZM-Mkt',
#  'Todd Schimelfenig': u'US-Pon,US-Shd,US-Ne1,US-Ne2,US-Ne3',
#  'Tom Kolb': u'US-Fuf,US-Fmf,US-Fwf',
#  "Tom O'Halloran": u'US-SBC',
#  'Tom Powell': u'US-KS1,US-KS2',
#  'Tomasz Staszewski': u'PL-Bre',
#  'Tomoomi Kumagai': u'MY-Lam',
#  'Tony Cahill': u'CR-SoC',
#  'Tony Scott': u'UK-Her',
#  'Torben Christensen': u'NO-Adv,SE-St2,SE-St1',
#  'Torbern Tagesson': u'SN-Dhr',
#  'Torbjorn Johansson': u'SE-Abi,SE-St2',
#  'Torsten Sachs': u'DE-Zrk,RU-Sam',
#  'Toru Iwata': u'JP-Hac',
#  'Toshihiko Maitani': u'CN-Zha',
#  'Trofim Maximov': u'RU-SkP,RU-Ylr,RU-Ypn',
#  'Tsutom Hiura': u'JP-Hok',
#  'Tulio Arredondo': u'MX-Oju',
#  'Tuomas Laurila': u'FI-Kns,FI-Let,FI-Lom,RU-Tks,FI-Jok,FI-Kaa,FI-Alk,FI-Sod',
#  'Tyler Roman': u'US-Cst',
#  'Tymoteusz Bolewski': u'PL-Bdg,PL-Wlw',
#  'Ulrike Falk': u'BF-Bon,BF-Btd',
#  'Umberto di': u'IT-Tor,IT-TrF',
#  'Unaffiliated': u'CA-Wes',
#  'Urmas H\xc3\xb5rrak': u'EE-Jvs',
#  'V.K. Dadhwal': u'ID-Kan,IN-Brk,IN-Hdw',
#  'Valerio Moretti': u'IT-Cp2',
#  'Vic Engel': u'US-Skr',
#  'Victor de': u'ES-QdM',
#  'Volodymyr Medinets': u'UA-Pet',
#  'Walter Oechel': u'US-Upa,US-SO4,US-SO2,US-SO3,US-Bes,MX-Lpa,RU-Cuk,US-Ivo,US-Atq,US-Brw,US-HVa',
#  'Warren  Helgason': u'CA-Ojp',
#  'Wayne Meyer': u'AU-Cpr',
#  'Weiguo Wang': u'US-PFa,US-WCr,US-Los',
#  'Wendell Cropper': u'US-SP1',
#  'Werner Eugster': u'CH-Aws,CH-Lae,CH-Oe2,CH-See,CH-Dav',
#  'Werner Kutsch': u'ZM-Mon,DE-Kan,DE-Wet',
#  'Whitney Moore': u'US-Bsg,US-Wgr,US-Wpp,US-Wwt',
#  'William (Bill) Parton': u'US-Vca',
#  'William Massman': u'US-GBT,US-GLE',
#  'William Mitsch': u'US-ORv',
#  'William Smith': u'US-NPn',
#  'Wilma Jans': u'NL-Haa,NL-Lan,NL-Mol,NL-Vre,NL-Lut,NL-Dij,NL-Waa,NL-Zee,NL-Ca1,NL-Loo',
#  'Wlodzimierz Pawlak': u'PL-Kpt',
#  'Wonsik Kim': u'TH-Mix',
#  'Xin Xiaoping': u'CN-Hug',
#  'Xuhui Lee': u'US-GMF',
#  'Yanbin Hao': u'MN-Inn',
#  'Yanfen Wang': u'MN-Inn',
#  'Yann Nouvellon': u'CG-Tch,CG-Hin,CG-Kis,CG-Euc',
#  'Yasuko Mizoguchi': u'JP-Fuj',
#  'Yiping Zhang': u'CN-Ail,CN-Xsh',
#  'Yojiro Matsura': u'RU-Tur,JP-Hit',
#  'Yoshiko Kosugi': u'JP-Aou,JP-KEW,MY-PSO',
#  'Yoshitaka Kakubari': u'JP-Nae',
#  'You Wang': u'NL-Hor',
#  'Yousei Hayashi': u'NZ-Pur',
#  'Yu Qiang': u'CN-Yuc',
#  'Yue-Joe Hsia': u'TW-Chn',
#  'Yuji Kominami': u'JP-YMS',
#  'Yukio Yasuda': u'JP-APP,JP-App,JP-Kwa',
#  'Yumiko Tanaka': u'JP-Hok',
#  'Zhao Xinquan': u'CN-Ha2,CN-Ha3,CN-Hab',
#  'Zhiqiang Zhang': u'CN-Bed',
#  'Zhou Guoyi': u'CN-Din',
#  'Zoltan Barcza': u'HU-He1,HU-He2',
#  'Zoltan Nagy': u'HU-Bug,HU-Mat',
#  'Zsolt Csintalan': u'HU-Mat',
#  'Zulia Sanchez-Mejia': u'US-StJ',
#  'nelius foley': u'IE-Dgm,IE-Dri,IE-Kil',
#  '\xc3\x81ngel Garc\xc3\xada': u'ES-QdM',
#  '\xc3\x9clo Mander': u'EE-Aar,EE-Hi1,EE-Hi2,EE-Ka1,EE-Ka2,EE-Ka3,EE-Ku1,EE-Ku2,EE-Lv1,EE-Lv2,EE-Lv3,EE-Mam,EE-Pdv,EE-Ph1,EE-Ph2,EE-Rok,EE-San,EE-Vg1,EE-Vg2'}

# %% [markdown]
# ### 1.3 Save processed data to disk

# %%
Fileoutput = open('D:/_Research/Project_Sharing_Data_FromLinux/ProjectRebuild_2017/Data/SiteInfo/InvestSite.txt','w')
for investor in InvestList:
    print >> Fileoutput, investor + '|' + str(Invest_Site[investor])
Fileoutput.close()

# %% [markdown]
# ## 2. Web of Science raw data processing
# Web of Science full records directly download form WoS interface are important resources for bibliometrics analysis, while they are in the form of TAG + contents, it is not convinient for python to handle. We'll transform it into a more neat form, then save those beautiful new Records to disk for further processing.
#
# ### 2.1 Load the data by Tags
# The downloaded WoS full record data was coded in UTF-8, which contained \xef\xbb\xbf and TM codes in the head. Delete them! Here the original data is rather small, We'll dump in the Web of Science ISI data into our memory directly. Usually this process should be done Line by Line, putting all files into memory is not a good way in processing a great bunch of data.

# %%
import pandas as pd

Fileinput = open('D:/_Research/Project_Sharing_Data_FromLinux/ProjectRebuild_2017/Data/5654Records_Original.txt')

#Set Reocrds as a List and each reocord as a dict to save attributes
Records = []
record = {}
CurrentTag = ''

for line in Fileinput.readlines():
    #Delete BOM Data in front, TM symbol in middle and \n in the last
    line = line.replace('\xef\xbb\xbf','').replace('\xe2\x84\xa2','').replace('\n','')
    #Extraction
    if line[:2] != '  ' and len(line) > 0:
        CurrentTag = line[:2]
        if CurrentTag != 'ER':
            record.update({CurrentTag:[line[3:]]})
        elif line[:2] == 'ER':
            Records.append(record)
            record = {}
    elif line[:2] == '  ':
        record[CurrentTag].append(line[3:])
        
Fileinput.close()

# %% [markdown]
# ### 2.2 New record structure
# Now the raw data are already well saved in Records, and they could also be processed in python. All attributes are recorded as Lists in memory. For single value attributes, there is only one value in the list, we'll transform them back to normal string. While for multi-value atrributes like AF, AU and CR, values are  well listed in the data structure.
# Transport the data into a 2D chart(pandas.DataFrame), let's see how they look like.

# %%
for index,record in enumerate(Records):
    for attr in record:
        if isinstance(record[attr],list):
            temp = ''
            for line in record[attr]:
                temp += line + '|'
            Records[index][attr] = temp[:-1]
    
PRecords = pd.DataFrame.from_records(Records, index = range(len(Records)))
PRecords
# Out:
#                                                      AB  \
# 0     In this study, net surface radiation (R-n) was...
# 1     To date, direct validation of city-wide emissi...
# 2     Large variability in N2O emissions from manage...
# 3     Conversions of natural ecosystems, e.g., from ...
# 4     A scheme describing the process of stream-aqui...
# 5     There have been few studies conducted on the c...
# 6     The lifetime of nitrogen oxides (NOx) affects ...
# 7     The emission, dispersion, and photochemistry o...
# 8     We measured volatile organic compounds (VOCs),...
# 9     The dry component of total nitrogen and sulfur...
# 10    In June and July 2011 the RPAS (Remotely Pilot...
# 11    Snow cover is one of the key factors controlli...
# 12    Plant water-use efficiency (WUE), which is the...
# 13    Accurate real-time monitoring of the variabili...
# 14    As a consequence of long-range transported pol...
# 15    This paper reports the fluxes and mixing ratio...
# 16    Recently, the number and amount of biogenicall...
# 17    Intensification of pastoral agriculture is occ...
# 18    Carbon (C) sequestration in the soil is consid...
# 19    Drained peatlands often act as carbon dioxide ...
# 20    Effects of hydraulic redistribution (HR) on hy...
# 21    Recent technological advances have enabled the...
# 22    Soil carbon stored in high-latitude permafrost...
# 23    Forest thinning, which removes some individual...
# 24    Savanna ecosystems cover 20% of the global lan...
# 25    The understanding of the continental carbon bu...
# 26    Boreal Eurasia is a region where the interacti...
# 27    Estimating evaporation is important when manag...
# 28    The WAter Cycle Multi-mission Observation Stra...
# 29    The WAter Cycle Multi-mission Observation Stra...
# ...                                                 ...
# 5624  It has been suggested in Part I of this paper ...
# 5625  Measurements of a scalar flux from an extended...
# 5626  A fast response tunable diode laser spectromet...
# 5627  Measurement of meteorological quantities with ...
# 5628  1. Tree transpiration, E(t), and understorey e...
# 5629  A composite life cycle of the Madden-Julian os...
# 5630  During the last two decades, different scaling...
# 5631  A high-resolution global model forecast of the...
# 5632  Aircraft-based observations of turbulence fiel...
# 5633  Plants and soils act as major sinks for the de...
# 5634  This study examines the influence of coherent ...
# 5635  Analysis of measurements from two long-term mo...
# 5636  Signal processing technique for detecting ocea...
# 5637  A small, lightweight and fast-response ozone s...
# 5638  A comprehensive study of atmospheric turbulenc...
# 5639  A two-source (Penman Monteith type) model, use...
# 5640  A new approach for calculating the concentrati...
# 5641  Total evaporation (E), forest floor evaporatio...
# 5642  Eddy fluxes of CO2 estimated using a sonic ane...
# 5643  A concerted effort has been made to simulate t...
# 5644  A hybrid model is developed and implemented fo...
# 5645  The meteorological structure of contrasting we...
# 5646  From 1979 to 1989, global European Centre for ...
# 5647  Optimal interpolation (OI) has been used to pr...
# 5648  A new analysis of the historical temperature a...
# 5649  An objective analysis scheme has been modified...
# 5650  A method combining sensible heat flux measurem...
# 5651                                                NaN
# 5652  A 30-year experiment with an atmospheric gener...
# 5653                                                NaN
#
#                                                      AF       AR  \
# 0     Mahalakshmi, D. V.|Paul, Arati|Dutta, D.|Ali, ...      NaN
# 1     Vaughan, Adam R.|Lee, James D.|Misztal, Pawel ...      NaN
# 2     Grant, Robert F.|Neftel, Albrecht|Calanca, Pie...      NaN
# 3     Merten, Jennifer|Roell, Alexander|Guillaume, T...        5
# 4     Zeng, Yujin|Xie, Zhenghui|Yu, Yan|Liu, Shuang|...      NaN
# 5                  Yang, Zesu|Zhang, Qiang|Hao, Xiaocui  6809749
# 6     Romer, Paul S.|Duffey, Kaitlin C.|Wooldridge, ...      NaN
# 7     Su, Luping|Patton, Edward G.|de Arellano, Jord...      NaN
# 8     Rantala, Pekka|Jarvi, Leena|Taipale, Risto|Lau...      NaN
# 9                        Rumsey, Ian C.|Walker, John T.      NaN
# 10    Reuder, Joachim|Baserud, Line|Jonassen, Marius...      NaN
# 11    Stiegler, Christian|Lund, Magnus|Christensen, ...      NaN
# 12    Dekker, Stefan C.|Groenendijk, Margriet|Booth,...      NaN
# 13                              Xu, Xibao|Tang, Xuguang      NaN
# 14    Lammel, Gerhard|Meixner, Franz X.|Vrana, Brani...      NaN
# 15    Acton, W. Joe F.|Schallhart, Simon|Langford, B...      NaN
# 16    Schallhart, Simon|Rantala, Pekka|Nemitz, Eiko|...      NaN
# 17    Hunt, John E.|Laubach, Johannes|Barthel, Matti...      NaN
# 18    Felber, Raphael|Bretscher, Daniel|Munger, Andr...      NaN
# 19    Franz, Daniela|Koebsch, Franziska|Larmanou, Er...      NaN
# 20    Fu, Congsheng|Wang, Guiling|Goulden, Michael L...      NaN
# 21    Gorres, Carolyn-Monika|Kammann, Claudia|Ceulem...      NaN
# 22    Cassidy, Alison E.|Christen, Andreas|Henry, Gr...      NaN
# 23    Wilkinson, Matthew|Crow, Peter|Eaton, Edward L...      NaN
# 24    Moore, Caitlin E.|Beringer, Jason|Evans, Bradl...      NaN
# 25    Satar, Ece|Berhanu, Tesfaye A.|Brunner, Domini...      NaN
# 26    van der Molen, M. K.|de Jeu, R. A. M.|Wagner, ...      NaN
# 27    Hoffmann, H.|Nieto, H.|Jensen, R.|Guzinski, R....      NaN
# 28    Michel, D.|Jimenez, C.|Miralles, D. G.|Jung, M...      NaN
# 29    Miralles, D. G.|Jimenez, C.|Jung, M.|Michel, D...      NaN
# ...                                                 ...      ...
# 5624       BRUNET, Y|ITIER, B|MCANENEY, J|LAGOUARDE, JP      NaN
# 5625                                  LEE, XH|BLACK, TA      NaN
# 5626                   WIENHOLD, FG|FRAHM, H|HARRIS, GW      NaN
# 5627                            RISSMANN, J|TETZLAFF, G      NaN
# 5628     WHITEHEAD, D|KELLIHER, FM|LANE, PM|POLLOCK, DS      NaN
# 5629                               HENDON, HH|SALBY, ML      NaN
# 5630                                   ZILITINKEVICH, S      NaN
# 5631  KRISHNAMURTI, TN|BEDI, HS|OOSTERHOF, D|HARDIKE...      NaN
# 5632  CARAMORI, P|SCHUEPP, P|DESJARDINS, R|MACPHERSO...      NaN
# 5633  MASSMAN, WJ|PEDERSON, J|DELANY, A|GRANTZ, D|DE...      NaN
# 5634                                MAHRT, L|HOWELL, JF      NaN
# 5635                                           HOGG, NG      NaN
# 5636  BASU, S|GAIROLA, RM|VARMA, AK|GAUTAM, N|PANDEY...      NaN
# 5637                              GUSTEN, H|SCHURATH, U      NaN
# 5638                                    ROTH, M|OKE, TR      NaN
# 5639                                        MASSMAN, WJ      NaN
# 5640                                 KAPLAN, H|DINAR, N      NaN
# 5641  KELLIHER, FM|KOSTNER, BMM|HOLLINGER, DY|BYERS,...      NaN
# 5642                                LEUNING, R|KING, KM      NaN
# 5643                            SEMTNER, AJ|CHERVIN, RM      NaN
# 5644                      FRANKEL, SH|JIANG, TL|GIVI, P      NaN
# 5645                              MATARIRA, CH|JURY, MR      NaN
# 5646                                      TRENBERTH, KE      NaN
# 5647                           RIENECKER, MM|MILLER, RN      NaN
# 5648                          DUCHENE, C|FRANKIGNOUL, C      NaN
# 5649                    SANTOLERI, R|MARULLO, S|BOHM, E      NaN
# 5650                 DIAWARA, A|LOUSTAU, D|BERBIGIER, P      NaN
# 5651                            LEUNING, R|MONCRIEFF, J      NaN
# 5652                                   LAU, NC|NATH, MJ      NaN
# 5653         LEUNING, R|DENMEAD, OT|LANG, ARG|OHTAKI, E      NaN
#
#                                                      AU   BE   BN     BP   BS  \
# 0     Mahalakshmi, DV|Paul, A|Dutta, D|Ali, MM|Dadhw...  NaN  NaN      1  NaN
# 1     Vaughan, AR|Lee, JD|Misztal, PK|Metzger, S|Sha...  NaN  NaN    455  NaN
# 2                        Grant, RF|Neftel, A|Calanca, P  NaN  NaN   3549  NaN
# 3     Merten, J|Roll, A|Guillaume, T|Meijide, A|Tari...  NaN  NaN    NaN  NaN
# 4     Zeng, YJ|Xie, ZH|Yu, Y|Liu, S|Wang, LY|Jia, BH...  NaN  NaN   2333  NaN
# 5                             Yang, ZS|Zhang, Q|Hao, XC  NaN  NaN    NaN  NaN
# 6     Romer, PS|Duffey, KC|Wooldridge, PJ|Allen, HM|...  NaN  NaN   7623  NaN
# 7     Su, LP|Patton, EG|de Arellano, JVG|Guenther, A...  NaN  NaN   7725  NaN
# 8     Rantala, P|Jarvi, L|Taipale, R|Laurila, TK|Pat...  NaN  NaN   7981  NaN
# 9                                 Rumsey, IC|Walker, JT  NaN  NaN   2581  NaN
# 10    Reuder, J|Baserud, L|Jonassen, MO|Kral, ST|Mul...  NaN  NaN   2675  NaN
# 11    Stiegler, C|Lund, M|Christensen, TR|Mastepanov...  NaN  NaN   1395  NaN
# 12    Dekker, SC|Groenendijk, M|Booth, BBB|Huntingfo...  NaN  NaN    525  NaN
# 13                                      Xu, XB|Tang, XG  NaN  NaN   1383  NaN
# 14    Lammel, G|Meixner, FX|Vrana, B|Efstathiou, CI|...  NaN  NaN   6381  NaN
# 15    Acton, WJF|Schallhart, S|Langford, B|Valach, A...  NaN  NaN   7149  NaN
# 16    Schallhart, S|Rantala, P|Nemitz, E|Taipale, D|...  NaN  NaN   7171  NaN
# 17    Hunt, JE|Laubach, J|Barthel, M|Fraser, A|Phill...  NaN  NaN   2927  NaN
# 18    Felber, R|Bretscher, D|Munger, A|Neftel, A|Amm...  NaN  NaN   2959  NaN
# 19    Franz, D|Koebsch, F|Larmanou, E|Augustin, J|Sa...  NaN  NaN   3051  NaN
# 20    Fu, CS|Wang, GL|Goulden, ML|Scott, RL|Bible, K...  NaN  NaN   2001  NaN
# 21                   Gorres, CM|Kammann, C|Ceulemans, R  NaN  NaN   1949  NaN
# 22                   Cassidy, AE|Christen, A|Henry, GHR  NaN  NaN   2291  NaN
# 23          Wilkinson, M|Crow, P|Eaton, EL|Morison, JIL  NaN  NaN   2367  NaN
# 24    Moore, CE|Beringer, J|Evans, B|Hutley, LB|McHu...  NaN  NaN   2387  NaN
# 25    Satar, E|Berhanu, TA|Brunner, D|Henne, S|Leuen...  NaN  NaN   2623  NaN
# 26    van der Molen, MK|de Jeu, RAM|Wagner, W|van de...  NaN  NaN    605  NaN
# 27    Hoffmann, H|Nieto, H|Jensen, R|Guzinski, R|Zar...  NaN  NaN    697  NaN
# 28    Michel, D|Jimenez, C|Miralles, DG|Jung, M|Hirs...  NaN  NaN    803  NaN
# 29    Miralles, DG|Jimenez, C|Jung, M|Michel, D|Ersh...  NaN  NaN    823  NaN
# ...                                                 ...  ...  ...    ...  ...
# 5624       BRUNET, Y|ITIER, B|MCANENEY, J|LAGOUARDE, JP  NaN  NaN    227  NaN
# 5625                                  LEE, XH|BLACK, TA  NaN  NaN  18545  NaN
# 5626                   WIENHOLD, FG|FRAHM, H|HARRIS, GW  NaN  NaN  16557  NaN
# 5627                            RISSMANN, J|TETZLAFF, G  NaN  NaN    293  NaN
# 5628     WHITEHEAD, D|KELLIHER, FM|LANE, PM|POLLOCK, DS  NaN  NaN    528  NaN
# 5629                               HENDON, HH|SALBY, ML  NaN  NaN   2225  NaN
# 5630                                   ZILITINKEVICH, S  NaN  NaN     51  NaN
# 5631  KRISHNAMURTI, TN|BEDI, HS|OOSTERHOF, D|HARDIKE...  NaN  NaN   1050  NaN
# 5632  CARAMORI, P|SCHUEPP, P|DESJARDINS, R|MACPHERSO...  NaN  NaN    627  NaN
# 5633  MASSMAN, WJ|PEDERSON, J|DELANY, A|GRANTZ, D|DE...  NaN  NaN   8281  NaN
# 5634                                MAHRT, L|HOWELL, JF  NaN  NaN    247  NaN
# 5635                                           HOGG, NG  NaN  NaN   2359  NaN
# 5636  BASU, S|GAIROLA, RM|VARMA, AK|GAUTAM, N|PANDEY...  NaN  NaN    188  NaN
# 5637                              GUSTEN, H|SCHURATH, U  NaN  NaN    324  NaN
# 5638                                    ROTH, M|OKE, TR  NaN  NaN   1071  NaN
# 5639                                        MASSMAN, WJ  NaN  NaN    167  NaN
# 5640                                 KAPLAN, H|DINAR, N  NaN  NaN    217  NaN
# 5641  KELLIHER, FM|KOSTNER, BMM|HOLLINGER, DY|BYERS,...  NaN  NaN     53  NaN
# 5642                                LEUNING, R|KING, KM  NaN  NaN    297  NaN
# 5643                            SEMTNER, AJ|CHERVIN, RM  NaN  NaN   5493  NaN
# 5644                      FRANKEL, SH|JIANG, TL|GIVI, P  NaN  NaN    535  NaN
# 5645                              MATARIRA, CH|JURY, MR  NaN  NaN    165  NaN
# 5646                                      TRENBERTH, KE  NaN  NaN   2159  NaN
# 5647                           RIENECKER, MM|MILLER, RN  NaN  NaN  15093  NaN
# 5648                          DUCHENE, C|FRANKIGNOUL, C  NaN  NaN    223  NaN
# 5649                    SANTOLERI, R|MARULLO, S|BOHM, E  NaN  NaN    681  NaN
# 5650                 DIAWARA, A|LOUSTAU, D|BERBIGIER, P  NaN  NaN     49  NaN
# 5651                            LEUNING, R|MONCRIEFF, J  NaN  NaN     63  NaN
# 5652                                   LAU, NC|NATH, MJ  NaN  NaN    965  NaN
# 5653         LEUNING, R|DENMEAD, OT|LANG, ARG|OHTAKI, E  NaN  NaN    209  NaN
#
#                                                      C1   CA ...    SU   TC  \
# 0     [Mahalakshmi, D. V.; Ali, M. M.; Dadhwal, V. K...  NaN ...   NaN    0
# 1     [Vaughan, Adam R.] Univ York, Dept Chem, York,...  NaN ...   NaN    3
# 2     [Grant, Robert F.] Univ Alberta, Dept Renewabl...  NaN ...   NaN    0
# 3     [Merten, Jennifer; Dittrich, Christoph; Faust,...  NaN ...   NaN    2
# 4     [Zeng, Yujin; Xie, Zhenghui; Liu, Shuang; Wang...  NaN ...   NaN    3
# 5     [Yang, Zesu] Chengdu Univ Informat Technol, Co...  NaN ...   NaN    0
# 6     [Romer, Paul S.; Duffey, Kaitlin C.; Wooldridg...  NaN ...   NaN    2
# 7     [Su, Luping; Mak, John E.] SUNY Stony Brook, S...  NaN ...   NaN    3
# 8     [Rantala, Pekka; Jarvi, Leena; Taipale, Risto;...  NaN ...   NaN    0
# 9     [Rumsey, Ian C.] Coll Charleston, Dept Phys & ...  NaN ...   NaN    0
# 10    [Reuder, Joachim; Baserud, Line; Jonassen, Mar...  NaN ...   NaN    2
# 11    [Stiegler, Christian; Lund, Magnus; Christense...  NaN ...   NaN    3
# 12    [Dekker, Stefan C.] Univ Utrecht, Fac Geosci, ...  NaN ...   NaN    1
# 13    [Xu, Xibao; Tang, Xuguang] Chinese Acad Sci, N...  NaN ...   NaN    0
# 14    [Lammel, Gerhard; Vrana, Branislav; Efstathiou...  NaN ...   NaN    4
# 15    [Acton, W. Joe F.; Valach, Amy; Hewitt, C. Nic...  NaN ...   NaN    1
# 16    [Schallhart, Simon; Rantala, Pekka; Taipale, D...  NaN ...   NaN    4
# 17    [Hunt, John E.; Laubach, Johannes; Barthel, Ma...  NaN ...   NaN    8
# 18    [Felber, Raphael; Bretscher, Daniel; Neftel, A...  NaN ...   NaN    3
# 19    [Franz, Daniela; Koebsch, Franziska; Larmanou,...  NaN ...   NaN    1
# 20    [Fu, Congsheng; Wang, Guiling] Univ Connecticu...  NaN ...   NaN    0
# 21    [Gorres, Carolyn-Monika; Ceulemans, Reinhart] ...  NaN ...   NaN    1
# 22    [Cassidy, Alison E.; Christen, Andreas; Henry,...  NaN ...   NaN    1
# 23    [Wilkinson, Matthew; Eaton, Edward L.; Morison...  NaN ...   NaN    0
# 24    [Moore, Caitlin E.; Beringer, Jason; McHugh, I...  NaN ...   NaN    6
# 25    [Satar, Ece; Berhanu, Tesfaye A.; Leuenberger,...  NaN ...   NaN    1
# 26    [van der Molen, M. K.; van der Velde, I. R.; K...  NaN ...   NaN    1
# 27    [Hoffmann, H.; Nieto, H.; Jensen, R.; Guzinski...  NaN ...   NaN    5
# 28    [Michel, D.; Hirschi, M.; Seneviratne, S. I.] ...  NaN ...   NaN    9
# 29    [Miralles, D. G.; Dolman, A. J.] Vrije Univ Am...  NaN ...   NaN   10
# ...                                                 ...  ... ...   ...  ...
# 5624  INRA,BIOCLIMATOL STN,F-78850 THIVERVAL GRIGNON...  NaN ...   NaN   24
# 5625  UNIV BRITISH COLUMBIA, DEPT SOIL SCI, VANCOUVE...  NaN ...   NaN   30
# 5626                                                NaN  NaN ...   NaN   59
# 5627  UNIV LEIPZIG,FACHBEREICH PHYS,INST METEOROL,D-...  NaN ...   NaN   20
# 5628  MANAAKI WHENUA LANDCARE RES,CHRISTCHURCH,NEW Z...  NaN ...   NaN   26
# 5629                                                NaN  NaN ...   NaN  423
# 5630                                                NaN  NaN ...   NaN   11
# 5631                                                NaN  NaN ...   NaN    7
# 5632  CTR LAND & BIOL RESOURCES RES,OTTAWA,ON,CANADA...  NaN ...   NaN   12
# 5633  CALIF AIR RESOURCES BOARD, SACRAMENTO, CA USA....  NaN ...   NaN   52
# 5634                                                NaN  NaN ...   NaN   36
# 5635                                                NaN  NaN ...   NaN   18
# 5636                                                NaN  NaN ...   NaN    4
# 5637                                                NaN  NaN ...   NaN    2
# 5638  UNIV BRITISH COLUMBIA,DEPT GEOG,ATMOSPHER SCI ...  NaN ...   NaN   61
# 5639                                                NaN  NaN ...   NaN   32
# 5640                                                NaN  NaN ...   NaN   11
# 5641  UNIV BAYREUTH,LEHRSTUHL PFLANZENOKOL,W-8580 BA...  NaN ...   NaN  121
# 5642  UNIV GUELPH,DEPT LAND RESOURCE SCI,GUELPH N1G ...  NaN ...   NaN   82
# 5643                                                NaN  NaN ...   NaN  414
# 5644                                                NaN  NaN ...   NaN   11
# 5645  UNIV CAPE TOWN, DEPT OCEANOG, RONDEBOSCH 7700,...  NaN ...   NaN   28
# 5646                                                NaN  NaN ...   NaN  262
# 5647  OREGON STATE UNIV,COLL OCEANOG,CORVALLIS,OR 97...  NaN ...   NaN   12
# 5648                                                NaN  NaN ...   NaN   13
# 5649  TELESPAZIO SPA,DIV EARTH OBSERVAT,I-00156 ROME...  NaN ...   NaN   11
# 5650     LAB SYLVICULTURE & ECOL,F-33610 CESTAS,FRANCE.  NaN ...   NaN   65
# 5651  UNIV EDINBURGH,DEPT FORESTRY & NAT RESOURCES,E...  NaN ...   NaN  169
# 5652                                                NaN  NaN ...   NaN  136
# 5653                                                NaN  NaN ...   NaN   53
#
#                                                      TI  U1  U2  \
# 0     Estimation of net surface radiation using eddy...   1   1
# 1     Spatially resolved flux measurements of NOx fr...   8  10
# 2     Ecological controls on N2O emission in surface...  11  12
# 3     Water scarcity and oil palm expansion: social ...  16  28
# 4     Ecohydrological effects of stream-aquifer wate...  10  15
# 5     Evapotranspiration Trend and Its Relationship ...   8   8
# 6     The lifetime of nitrogen oxides in an isoprene...  16  26
# 7     Understanding isoprene photooxidation using ob...   7  10
# 8     Anthropogenic and biogenic influence on VOC fl...   3  12
# 9     Application of an online ion-chromatography-ba...   4  10
# 10    Exploring the potential of the RPA system SUMO...   0   0
# 11    Two years with extreme and little snowfall: ef...   3  10
# 12    Spatial and temporal variations in plant water...   9  12
# 13    REMOTE ESTIMATION OF ECOSYSTEM WATER-USE EFFIC...   1   1
# 14    Bidirectional air-sea exchange and accumulatio...  15  21
# 15    Canopy-scale flux measurements and bottom-up e...   2   8
# 16    Characterization of total ecosystem-scale biog...   2   7
# 17    Carbon budgets for an irrigated intensively gr...   3   6
# 18    Determination of the carbon budget of a pastur...   4   9
# 19    High net CO2 and CH4 release at a eutrophic sh...  10  22
# 20    Combined measurement and modeling of the hydro...   6  12
# 21    Automation of soil flux chamber measurements: ...  15  28
# 22    The effect of a permafrost disturbance on grow...   4   5
# 23    Effects of management thinning on CO2 exchange...  10  15
# 24    The contribution of trees and grasses to produ...   9  18
# 25    Continuous CO2/CH4/CO measurements (2012-2014)...   3  13
# 26    The effect of assimilating satellite-derived s...   7  11
# 27    Estimating evaporation with thermal UAV data a...   6  13
# 28    The WACMOS-ET project - Part 1: Tower-scale ev...  10  15
# 29    The WACMOS-ET project - Part 2: Evaluation of ...  14  22
# ...                                                 ...  ..  ..
# 5624  DOWNWIND EVOLUTION OF SCALAR FLUXES AND SURFAC...   1   2
# 5625  RELATING EDDY-CORRELATION SENSIBLE HEAT-FLUX T...   1   2
# 5626  MEASUREMENTS OF N2O FLUXES FROM FERTILIZED GRA...   0   8
# 5627  APPLICATION OF A SPECTRAL CORRECTION METHOD FO...   0   0
# 5628  SEASONAL PARTITIONING OF EVAPORATION BETWEEN T...   0   1
# 5629    THE LIFE-CYCLE OF THE MADDEN-JULIAN OSCILLATION   5  34
# 5630   A GENERALIZED SCALING FOR CONVECTIVE SHEAR FLOWS   0   2
# 5631        THE FORMATION OF HURRICANE-FREDERIC OF 1979   0   3
# 5632  STRUCTURAL-ANALYSIS OF AIRBORNE FLUX ESTIMATES...   0   1
# 5633  AN EVALUATION OF THE REGIONAL ACID DEPOSITION ...   0   5
# 5634  THE INFLUENCE OF COHERENT STRUCTURES AND MICRO...   0   3
# 5635  TOWARD PARAMETERIZATION OF THE EDDY FIELD NEAR...   0   0
# 5636  SATELLITE ALTIMETRIC DETECTION OF SOMALI EDDIE...   0   1
# 5637  A NOVEL OZONE SENSOR WITH VARIOUS ENVIRONMENTA...   0   0
# 5638  TURBULENT TRANSFER RELATIONSHIPS OVER AN URBAN...   2  11
# 5639  PARTITIONING OZONE FLUXES TO SPARSE GRASS AND ...   0   4
# 5640  A 3-DIMENSIONAL MODEL FOR CALCULATING THE CONC...   0   0
# 5641  EVAPORATION, XYLEM SAP FLOW, AND TREE TRANSPIR...   5  37
# 5642  COMPARISON OF EDDY-COVARIANCE MEASUREMENTS OF ...   1  14
# 5643  OCEAN GENERAL-CIRCULATION FROM A GLOBAL EDDY-R...   7  38
# 5644  MODELING OF ISOTROPIC REACTING TURBULENCE BY A...   0   1
# 5645  CONTRASTING METEOROLOGICAL STRUCTURE OF INTRA-...   0   1
# 5646            STORM TRACKS IN THE SOUTHERN-HEMISPHERE   5  22
# 5647  OCEAN DATA ASSIMILATION USING OPTIMAL INTERPOL...   0   2
# 5648  SEASONAL-VARIATIONS OF SURFACE DYNAMIC TOPOGRA...   0   1
# 5649     AN OBJECTIVE ANALYSIS SCHEME FOR AVHRR IMAGERY   0   1
# 5650  COMPARISON OF 2 METHODS FOR ESTIMATING THE EVA...   2  16
# 5651  EDDY-COVARIANCE CO2 FLUX MEASUREMENTS USING OP...   2  13
# 5652  A GENERAL-CIRCULATION MODEL STUDY OF THE ATMOS...   0   1
# 5653  EFFECTS OF HEAT AND WATER-VAPOR TRANSPORT ON E...   4  15
#
#                        UT   VL   VR  \
# 0     WOS:000381162400001   33  1.0
# 1     WOS:000380099700022  189  NaN
# 2     WOS:000379427700003   13  NaN
# 3     WOS:000380049100006   21  NaN
# 4     WOS:000379419500013   20  NaN
# 5     WOS:000379433600001  NaN  NaN
# 6     WOS:000379417300009   16  NaN
# 7     WOS:000379417300016   16  NaN
# 8     WOS:000379417300032   16  NaN
# 9     WOS:000379397100008    9  NaN
# 10    WOS:000379397100015    9  NaN
# 11    WOS:000379422700003   10  NaN
# 12    WOS:000379425700014    7  NaN
# 13    WOS:000378967600011   25  NaN
# 14    WOS:000378354100021   16  NaN
# 15    WOS:000378354600030   16  NaN
# 16    WOS:000378354600031   16  NaN
# 17    WOS:000378354900005   13  NaN
# 18    WOS:000378354900007   13  NaN
# 19    WOS:000378354900013   13  NaN
# 20    WOS:000377862900021   20  NaN
# 21    WOS:000377274100014   13  NaN
# 22    WOS:000377276700005   13  NaN
# 23    WOS:000377276700010   13  NaN
# 24    WOS:000377276700012   13  NaN
# 25    WOS:000377277300001   13  NaN
# 26    WOS:000377697600002   20  NaN
# 27    WOS:000377697600009   20  NaN
# 28    WOS:000377697600015   20  NaN
# 29    WOS:000377697600016   20  NaN
# ...                   ...  ...  ...
# 5624  WOS:A1994PP63600002   71  NaN
# 5625  WOS:A1994PH35700004   99  NaN
# 5626  WOS:A1994PC94400018   99  NaN
# 5627  WOS:A1994PE93900004   70  NaN
# 5628  WOS:A1994PB91400011   31  NaN
# 5629  WOS:A1994NZ46100004   51  NaN
# 5630  WOS:A1994PD04200004   70  NaN
# 5631  WOS:A1994NQ15600003  122  NaN
# 5632  WOS:A1994NL46500002    7  NaN
# 5633  WOS:A1994NH26300020   99  NaN
# 5634  WOS:A1994MZ16300010  260  NaN
# 5635  WOS:A1993MP73300017   40  NaN
# 5636  WOS:A1993MA24400006   22  NaN
# 5637  WOS:A1993MC24800002  103  NaN
# 5638  WOS:A1993LV83100010  119  NaN
# 5639  WOS:A1993KP20600006   27  NaN
# 5640  WOS:A1993KH51700014   62  NaN
# 5641  WOS:A1992KC98500004   62  NaN
# 5642  WOS:A1992HV73400007   59  NaN
# 5643  WOS:A1992HQ25600024   97  NaN
# 5644  WOS:A1992HP46900006   38  NaN
# 5645  WOS:A1992HJ79700004   12  NaN
# 5646  WOS:A1991GQ81100004   48  NaN
# 5647  WOS:A1991GB33700026   96  NaN
# 5648  WOS:A1991FY14300001   49  NaN
# 5649  WOS:A1991FD71600003   12  NaN
# 5650  WOS:A1991FH04300003   54  NaN
# 5651  WOS:A1990EE37800006   53  NaN
# 5652  WOS:A1990FC72000003    3  NaN
# 5653  WOS:A1982PC59700007   23  NaN
#
#                                                      WC   Z9
# 0                             Geochemistry & Geophysics    0
# 1                                   Chemistry, Physical    3
# 2               Ecology; Geosciences, Multidisciplinary    0
# 3                        Ecology; Environmental Studies    2
# 4       Geosciences, Multidisciplinary; Water Resources    3
# 5                    Meteorology & Atmospheric Sciences    0
# 6                    Meteorology & Atmospheric Sciences    2
# 7                    Meteorology & Atmospheric Sciences    3
# 8                    Meteorology & Atmospheric Sciences    0
# 9                    Meteorology & Atmospheric Sciences    0
# 10                   Meteorology & Atmospheric Sciences    2
# 11    Geography, Physical; Geosciences, Multidiscipl...    3
# 12                       Geosciences, Multidisciplinary    1
# 13                               Environmental Sciences    0
# 14                   Meteorology & Atmospheric Sciences    4
# 15                   Meteorology & Atmospheric Sciences    1
# 16                   Meteorology & Atmospheric Sciences    4
# 17              Ecology; Geosciences, Multidisciplinary    8
# 18              Ecology; Geosciences, Multidisciplinary    3
# 19              Ecology; Geosciences, Multidisciplinary    1
# 20      Geosciences, Multidisciplinary; Water Resources    0
# 21              Ecology; Geosciences, Multidisciplinary    1
# 22              Ecology; Geosciences, Multidisciplinary    1
# 23              Ecology; Geosciences, Multidisciplinary    0
# 24              Ecology; Geosciences, Multidisciplinary    6
# 25              Ecology; Geosciences, Multidisciplinary    1
# 26      Geosciences, Multidisciplinary; Water Resources    1
# 27      Geosciences, Multidisciplinary; Water Resources    5
# 28      Geosciences, Multidisciplinary; Water Resources    9
# 29      Geosciences, Multidisciplinary; Water Resources   10
# ...                                                 ...  ...
# 5624  Agronomy; Forestry; Meteorology & Atmospheric ...   24
# 5625                 Meteorology & Atmospheric Sciences   30
# 5626                 Meteorology & Atmospheric Sciences   60
# 5627                 Meteorology & Atmospheric Sciences   21
# 5628                 Biodiversity Conservation; Ecology   26
# 5629                 Meteorology & Atmospheric Sciences  428
# 5630                 Meteorology & Atmospheric Sciences   11
# 5631                 Meteorology & Atmospheric Sciences    7
# 5632                 Meteorology & Atmospheric Sciences   12
# 5633                 Meteorology & Atmospheric Sciences   55
# 5634               Mechanics; Physics, Fluids & Plasmas   36
# 5635                                       Oceanography   18
# 5636                                       Oceanography    4
# 5637  Engineering, Multidisciplinary; Instruments & ...    2
# 5638                 Meteorology & Atmospheric Sciences   71
# 5639  Environmental Sciences; Meteorology & Atmosphe...   32
# 5640                 Meteorology & Atmospheric Sciences   11
# 5641  Agronomy; Forestry; Meteorology & Atmospheric ...  126
# 5642                 Meteorology & Atmospheric Sciences   90
# 5643                                       Oceanography  422
# 5644                              Engineering, Chemical   11
# 5645                 Meteorology & Atmospheric Sciences   28
# 5646                 Meteorology & Atmospheric Sciences  268
# 5647                                       Oceanography   12
# 5648                                       Oceanography   13
# 5649  Remote Sensing; Imaging Science & Photographic...   11
# 5650  Agronomy; Forestry; Meteorology & Atmospheric ...   71
# 5651                 Meteorology & Atmospheric Sciences  176
# 5652                 Meteorology & Atmospheric Sciences  143
# 5653                 Meteorology & Atmospheric Sciences   56
#
# [5654 rows x 62 columns]

# %% [markdown]
# ### 2.3 Data output
# Just output the whole dataframe to one single xlsx file using the function pandas.DataFrame.to_excel and pandas.DataFrame.to_csv().

# %%
import sys
reload(sys)
sys.setdefaultencoding('utf8')

writer = pd.ExcelWriter('D:/_Research/Project_Sharing_Data_FromLinux/ProjectRebuild_2017/Data/Full_Record_WoS.xlsx')
PRecords.to_excel(writer, 'Sheet1')
writer.save()

# %%
PRecords.to_csv('D:/_Research/Project_Sharing_Data_FromLinux/ProjectRebuild_2017/Data/Full_Record_WoS.csv')
