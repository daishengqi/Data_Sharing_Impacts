# %% [markdown]
# # Combine authors in Web of Science and investors in flux sites
# In this section, what we wanna do is tag those authors who also acted as investors of flux sites, thus further we can check the relationship between scholar publishments and research facilities. The only avaliable key that connects both Web of Science and Flux site datasets is the name. While for a single author/investor, his/her name will falls into multiple forms. So the primary job here is to find all duplicate names and bind them to one person.
#
# ### 1. Data structure
# Before diving into the real datasets, we should design neat data structures to handle authors.

# %%
class NameSequence(object):
    def __init__(self, namestring): #Initialize the name from raw data, turn name into three parts
        if ',' in namestring:
            temp = namestring.split(', ')
            self.FP = temp[0].translate(None,punctuation)
            secondpart = temp[1].translate(None,punctuation)
            if len(secondpart.split(' ')) > 1:
                self.SP = secondpart.split(' ')[0]
                self.MD = secondpart.split(' ')[1]
            else:
                self.SP = secondpart
                self.MD = ''
        elif ' ' in namestring:
            temp = namestring.split(' ')
            self.FP = temp[0].translate(None,punctuation)
            self.SP = temp[1].translate(None,punctuation)
            self.MD = ''
        else:
            self.FP = namestring
            self.SP = ' '
            self.MD = ''
    #Print the full name out
    def Printout(self):
        print(self.FP,self.SP,self.MD)
        
#Author definition
class Author(object):
    def __init__(self, *args, **kwargs):
        self.Name = [kwargs['Name']]
        self.Short = [kwargs['Short']]
        self.Paper = [kwargs['Paper']]
        self.POI = [kwargs['POI']]
        self.isReprint = [kwargs['isReprint']]
        self.isFirst = [kwargs['isFirst']]
        self.Multiname = 0
        self.isInvest = 0
        self.Site = []
        self.attr = kwargs
        
    def Attach(self, single):
        self.Name.extend(single.Name)
        self.Short.extend(single.Short)
        self.Paper.extend(single.Paper)
        self.POI.extend(single.POI)
        self.isReprint.extend(single.isReprint)
        self.isFirst.extend(single.isFirst)
        self.Multiname += 1
                
    def PrintName(self):
        for name in self.Name:
            name.Printout()
    
    def PrintPaper(self):
        for paper in self.Paper:
            print(paper)

class Investor(object):
    def __init__(self, name, sites):
        self.Name = name
        self.Sites = sites

# %% [markdown]
# ### 2. Load libraries and Web of Science data

# %%
import pandas as pd
import difflib as dif
from string import punctuation
    
PRecords = pd.read_csv('D:/_Research/Project_Sharing_Data_FromLinux/ProjectRebuild_2017/Data/Full_Record_WoS.csv', sep = ',', encoding = 'utf-8')
PRecords = PRecords.drop('Unnamed: 0', axis = 1)
PRecords
# Out:
#                                                      AB  \
# 0     In this study, net surface radiation (R-n) was...
# 1     To date, direct validation of city-wide emissi...
# 2     Large variability in N2O emissions from manage...
# 3     Conversions of natural ecosystems, e.g., from ...
# 4     A scheme describing the process of stream-aqui...
# 5     There have been few studies conducted on the c...
# 6     The lifetime of nitrogen oxides (NOx) affects ...
# 7     The emission, dispersion, and photochemistry o...
# 8     We measured volatile organic compounds (VOCs),...
# 9     The dry component of total nitrogen and sulfur...
# 10    In June and July 2011 the RPAS (Remotely Pilot...
# 11    Snow cover is one of the key factors controlli...
# 12    Plant water-use efficiency (WUE), which is the...
# 13    Accurate real-time monitoring of the variabili...
# 14    As a consequence of long-range transported pol...
# 15    This paper reports the fluxes and mixing ratio...
# 16    Recently, the number and amount of biogenicall...
# 17    Intensification of pastoral agriculture is occ...
# 18    Carbon (C) sequestration in the soil is consid...
# 19    Drained peatlands often act as carbon dioxide ...
# 20    Effects of hydraulic redistribution (HR) on hy...
# 21    Recent technological advances have enabled the...
# 22    Soil carbon stored in high-latitude permafrost...
# 23    Forest thinning, which removes some individual...
# 24    Savanna ecosystems cover 20% of the global lan...
# 25    The understanding of the continental carbon bu...
# 26    Boreal Eurasia is a region where the interacti...
# 27    Estimating evaporation is important when manag...
# 28    The WAter Cycle Multi-mission Observation Stra...
# 29    The WAter Cycle Multi-mission Observation Stra...
# ...                                                 ...
# 5624  It has been suggested in Part I of this paper ...
# 5625  Measurements of a scalar flux from an extended...
# 5626  A fast response tunable diode laser spectromet...
# 5627  Measurement of meteorological quantities with ...
# 5628  1. Tree transpiration, E(t), and understorey e...
# 5629  A composite life cycle of the Madden-Julian os...
# 5630  During the last two decades, different scaling...
# 5631  A high-resolution global model forecast of the...
# 5632  Aircraft-based observations of turbulence fiel...
# 5633  Plants and soils act as major sinks for the de...
# 5634  This study examines the influence of coherent ...
# 5635  Analysis of measurements from two long-term mo...
# 5636  Signal processing technique for detecting ocea...
# 5637  A small, lightweight and fast-response ozone s...
# 5638  A comprehensive study of atmospheric turbulenc...
# 5639  A two-source (Penman Monteith type) model, use...
# 5640  A new approach for calculating the concentrati...
# 5641  Total evaporation (E), forest floor evaporatio...
# 5642  Eddy fluxes of CO2 estimated using a sonic ane...
# 5643  A concerted effort has been made to simulate t...
# 5644  A hybrid model is developed and implemented fo...
# 5645  The meteorological structure of contrasting we...
# 5646  From 1979 to 1989, global European Centre for ...
# 5647  Optimal interpolation (OI) has been used to pr...
# 5648  A new analysis of the historical temperature a...
# 5649  An objective analysis scheme has been modified...
# 5650  A method combining sensible heat flux measurem...
# 5651                                                NaN
# 5652  A 30-year experiment with an atmospheric gener...
# 5653                                                NaN
#
#                                                      AF       AR  \
# 0     Mahalakshmi, D. V.|Paul, Arati|Dutta, D.|Ali, ...      NaN
# 1     Vaughan, Adam R.|Lee, James D.|Misztal, Pawel ...      NaN
# 2     Grant, Robert F.|Neftel, Albrecht|Calanca, Pie...      NaN
# 3     Merten, Jennifer|Roell, Alexander|Guillaume, T...        5
# 4     Zeng, Yujin|Xie, Zhenghui|Yu, Yan|Liu, Shuang|...      NaN
# 5                  Yang, Zesu|Zhang, Qiang|Hao, Xiaocui  6809749
# 6     Romer, Paul S.|Duffey, Kaitlin C.|Wooldridge, ...      NaN
# 7     Su, Luping|Patton, Edward G.|de Arellano, Jord...      NaN
# 8     Rantala, Pekka|Jarvi, Leena|Taipale, Risto|Lau...      NaN
# 9                        Rumsey, Ian C.|Walker, John T.      NaN
# 10    Reuder, Joachim|Baserud, Line|Jonassen, Marius...      NaN
# 11    Stiegler, Christian|Lund, Magnus|Christensen, ...      NaN
# 12    Dekker, Stefan C.|Groenendijk, Margriet|Booth,...      NaN
# 13                              Xu, Xibao|Tang, Xuguang      NaN
# 14    Lammel, Gerhard|Meixner, Franz X.|Vrana, Brani...      NaN
# 15    Acton, W. Joe F.|Schallhart, Simon|Langford, B...      NaN
# 16    Schallhart, Simon|Rantala, Pekka|Nemitz, Eiko|...      NaN
# 17    Hunt, John E.|Laubach, Johannes|Barthel, Matti...      NaN
# 18    Felber, Raphael|Bretscher, Daniel|Munger, Andr...      NaN
# 19    Franz, Daniela|Koebsch, Franziska|Larmanou, Er...      NaN
# 20    Fu, Congsheng|Wang, Guiling|Goulden, Michael L...      NaN
# 21    Gorres, Carolyn-Monika|Kammann, Claudia|Ceulem...      NaN
# 22    Cassidy, Alison E.|Christen, Andreas|Henry, Gr...      NaN
# 23    Wilkinson, Matthew|Crow, Peter|Eaton, Edward L...      NaN
# 24    Moore, Caitlin E.|Beringer, Jason|Evans, Bradl...      NaN
# 25    Satar, Ece|Berhanu, Tesfaye A.|Brunner, Domini...      NaN
# 26    van der Molen, M. K.|de Jeu, R. A. M.|Wagner, ...      NaN
# 27    Hoffmann, H.|Nieto, H.|Jensen, R.|Guzinski, R....      NaN
# 28    Michel, D.|Jimenez, C.|Miralles, D. G.|Jung, M...      NaN
# 29    Miralles, D. G.|Jimenez, C.|Jung, M.|Michel, D...      NaN
# ...                                                 ...      ...
# 5624       BRUNET, Y|ITIER, B|MCANENEY, J|LAGOUARDE, JP      NaN
# 5625                                  LEE, XH|BLACK, TA      NaN
# 5626                   WIENHOLD, FG|FRAHM, H|HARRIS, GW      NaN
# 5627                            RISSMANN, J|TETZLAFF, G      NaN
# 5628     WHITEHEAD, D|KELLIHER, FM|LANE, PM|POLLOCK, DS      NaN
# 5629                               HENDON, HH|SALBY, ML      NaN
# 5630                                   ZILITINKEVICH, S      NaN
# 5631  KRISHNAMURTI, TN|BEDI, HS|OOSTERHOF, D|HARDIKE...      NaN
# 5632  CARAMORI, P|SCHUEPP, P|DESJARDINS, R|MACPHERSO...      NaN
# 5633  MASSMAN, WJ|PEDERSON, J|DELANY, A|GRANTZ, D|DE...      NaN
# 5634                                MAHRT, L|HOWELL, JF      NaN
# 5635                                           HOGG, NG      NaN
# 5636  BASU, S|GAIROLA, RM|VARMA, AK|GAUTAM, N|PANDEY...      NaN
# 5637                              GUSTEN, H|SCHURATH, U      NaN
# 5638                                    ROTH, M|OKE, TR      NaN
# 5639                                        MASSMAN, WJ      NaN
# 5640                                 KAPLAN, H|DINAR, N      NaN
# 5641  KELLIHER, FM|KOSTNER, BMM|HOLLINGER, DY|BYERS,...      NaN
# 5642                                LEUNING, R|KING, KM      NaN
# 5643                            SEMTNER, AJ|CHERVIN, RM      NaN
# 5644                      FRANKEL, SH|JIANG, TL|GIVI, P      NaN
# 5645                              MATARIRA, CH|JURY, MR      NaN
# 5646                                      TRENBERTH, KE      NaN
# 5647                           RIENECKER, MM|MILLER, RN      NaN
# 5648                          DUCHENE, C|FRANKIGNOUL, C      NaN
# 5649                    SANTOLERI, R|MARULLO, S|BOHM, E      NaN
# 5650                 DIAWARA, A|LOUSTAU, D|BERBIGIER, P      NaN
# 5651                            LEUNING, R|MONCRIEFF, J      NaN
# 5652                                   LAU, NC|NATH, MJ      NaN
# 5653         LEUNING, R|DENMEAD, OT|LANG, ARG|OHTAKI, E      NaN
#
#                                                      AU   BE   BN     BP   BS  \
# 0     Mahalakshmi, DV|Paul, A|Dutta, D|Ali, MM|Dadhw...  NaN  NaN      1  NaN
# 1     Vaughan, AR|Lee, JD|Misztal, PK|Metzger, S|Sha...  NaN  NaN    455  NaN
# 2                        Grant, RF|Neftel, A|Calanca, P  NaN  NaN   3549  NaN
# 3     Merten, J|Roll, A|Guillaume, T|Meijide, A|Tari...  NaN  NaN    NaN  NaN
# 4     Zeng, YJ|Xie, ZH|Yu, Y|Liu, S|Wang, LY|Jia, BH...  NaN  NaN   2333  NaN
# 5                             Yang, ZS|Zhang, Q|Hao, XC  NaN  NaN    NaN  NaN
# 6     Romer, PS|Duffey, KC|Wooldridge, PJ|Allen, HM|...  NaN  NaN   7623  NaN
# 7     Su, LP|Patton, EG|de Arellano, JVG|Guenther, A...  NaN  NaN   7725  NaN
# 8     Rantala, P|Jarvi, L|Taipale, R|Laurila, TK|Pat...  NaN  NaN   7981  NaN
# 9                                 Rumsey, IC|Walker, JT  NaN  NaN   2581  NaN
# 10    Reuder, J|Baserud, L|Jonassen, MO|Kral, ST|Mul...  NaN  NaN   2675  NaN
# 11    Stiegler, C|Lund, M|Christensen, TR|Mastepanov...  NaN  NaN   1395  NaN
# 12    Dekker, SC|Groenendijk, M|Booth, BBB|Huntingfo...  NaN  NaN    525  NaN
# 13                                      Xu, XB|Tang, XG  NaN  NaN   1383  NaN
# 14    Lammel, G|Meixner, FX|Vrana, B|Efstathiou, CI|...  NaN  NaN   6381  NaN
# 15    Acton, WJF|Schallhart, S|Langford, B|Valach, A...  NaN  NaN   7149  NaN
# 16    Schallhart, S|Rantala, P|Nemitz, E|Taipale, D|...  NaN  NaN   7171  NaN
# 17    Hunt, JE|Laubach, J|Barthel, M|Fraser, A|Phill...  NaN  NaN   2927  NaN
# 18    Felber, R|Bretscher, D|Munger, A|Neftel, A|Amm...  NaN  NaN   2959  NaN
# 19    Franz, D|Koebsch, F|Larmanou, E|Augustin, J|Sa...  NaN  NaN   3051  NaN
# 20    Fu, CS|Wang, GL|Goulden, ML|Scott, RL|Bible, K...  NaN  NaN   2001  NaN
# 21                   Gorres, CM|Kammann, C|Ceulemans, R  NaN  NaN   1949  NaN
# 22                   Cassidy, AE|Christen, A|Henry, GHR  NaN  NaN   2291  NaN
# 23          Wilkinson, M|Crow, P|Eaton, EL|Morison, JIL  NaN  NaN   2367  NaN
# 24    Moore, CE|Beringer, J|Evans, B|Hutley, LB|McHu...  NaN  NaN   2387  NaN
# 25    Satar, E|Berhanu, TA|Brunner, D|Henne, S|Leuen...  NaN  NaN   2623  NaN
# 26    van der Molen, MK|de Jeu, RAM|Wagner, W|van de...  NaN  NaN    605  NaN
# 27    Hoffmann, H|Nieto, H|Jensen, R|Guzinski, R|Zar...  NaN  NaN    697  NaN
# 28    Michel, D|Jimenez, C|Miralles, DG|Jung, M|Hirs...  NaN  NaN    803  NaN
# 29    Miralles, DG|Jimenez, C|Jung, M|Michel, D|Ersh...  NaN  NaN    823  NaN
# ...                                                 ...  ...  ...    ...  ...
# 5624       BRUNET, Y|ITIER, B|MCANENEY, J|LAGOUARDE, JP  NaN  NaN    227  NaN
# 5625                                  LEE, XH|BLACK, TA  NaN  NaN  18545  NaN
# 5626                   WIENHOLD, FG|FRAHM, H|HARRIS, GW  NaN  NaN  16557  NaN
# 5627                            RISSMANN, J|TETZLAFF, G  NaN  NaN    293  NaN
# 5628     WHITEHEAD, D|KELLIHER, FM|LANE, PM|POLLOCK, DS  NaN  NaN    528  NaN
# 5629                               HENDON, HH|SALBY, ML  NaN  NaN   2225  NaN
# 5630                                   ZILITINKEVICH, S  NaN  NaN     51  NaN
# 5631  KRISHNAMURTI, TN|BEDI, HS|OOSTERHOF, D|HARDIKE...  NaN  NaN   1050  NaN
# 5632  CARAMORI, P|SCHUEPP, P|DESJARDINS, R|MACPHERSO...  NaN  NaN    627  NaN
# 5633  MASSMAN, WJ|PEDERSON, J|DELANY, A|GRANTZ, D|DE...  NaN  NaN   8281  NaN
# 5634                                MAHRT, L|HOWELL, JF  NaN  NaN    247  NaN
# 5635                                           HOGG, NG  NaN  NaN   2359  NaN
# 5636  BASU, S|GAIROLA, RM|VARMA, AK|GAUTAM, N|PANDEY...  NaN  NaN    188  NaN
# 5637                              GUSTEN, H|SCHURATH, U  NaN  NaN    324  NaN
# 5638                                    ROTH, M|OKE, TR  NaN  NaN   1071  NaN
# 5639                                        MASSMAN, WJ  NaN  NaN    167  NaN
# 5640                                 KAPLAN, H|DINAR, N  NaN  NaN    217  NaN
# 5641  KELLIHER, FM|KOSTNER, BMM|HOLLINGER, DY|BYERS,...  NaN  NaN     53  NaN
# 5642                                LEUNING, R|KING, KM  NaN  NaN    297  NaN
# 5643                            SEMTNER, AJ|CHERVIN, RM  NaN  NaN   5493  NaN
# 5644                      FRANKEL, SH|JIANG, TL|GIVI, P  NaN  NaN    535  NaN
# 5645                              MATARIRA, CH|JURY, MR  NaN  NaN    165  NaN
# 5646                                      TRENBERTH, KE  NaN  NaN   2159  NaN
# 5647                           RIENECKER, MM|MILLER, RN  NaN  NaN  15093  NaN
# 5648                          DUCHENE, C|FRANKIGNOUL, C  NaN  NaN    223  NaN
# 5649                    SANTOLERI, R|MARULLO, S|BOHM, E  NaN  NaN    681  NaN
# 5650                 DIAWARA, A|LOUSTAU, D|BERBIGIER, P  NaN  NaN     49  NaN
# 5651                            LEUNING, R|MONCRIEFF, J  NaN  NaN     63  NaN
# 5652                                   LAU, NC|NATH, MJ  NaN  NaN    965  NaN
# 5653         LEUNING, R|DENMEAD, OT|LANG, ARG|OHTAKI, E  NaN  NaN    209  NaN
#
#                                                      C1   CA ...    SU   TC  \
# 0     [Mahalakshmi, D. V.; Ali, M. M.; Dadhwal, V. K...  NaN ...   NaN    0
# 1     [Vaughan, Adam R.] Univ York, Dept Chem, York,...  NaN ...   NaN    3
# 2     [Grant, Robert F.] Univ Alberta, Dept Renewabl...  NaN ...   NaN    0
# 3     [Merten, Jennifer; Dittrich, Christoph; Faust,...  NaN ...   NaN    2
# 4     [Zeng, Yujin; Xie, Zhenghui; Liu, Shuang; Wang...  NaN ...   NaN    3
# 5     [Yang, Zesu] Chengdu Univ Informat Technol, Co...  NaN ...   NaN    0
# 6     [Romer, Paul S.; Duffey, Kaitlin C.; Wooldridg...  NaN ...   NaN    2
# 7     [Su, Luping; Mak, John E.] SUNY Stony Brook, S...  NaN ...   NaN    3
# 8     [Rantala, Pekka; Jarvi, Leena; Taipale, Risto;...  NaN ...   NaN    0
# 9     [Rumsey, Ian C.] Coll Charleston, Dept Phys & ...  NaN ...   NaN    0
# 10    [Reuder, Joachim; Baserud, Line; Jonassen, Mar...  NaN ...   NaN    2
# 11    [Stiegler, Christian; Lund, Magnus; Christense...  NaN ...   NaN    3
# 12    [Dekker, Stefan C.] Univ Utrecht, Fac Geosci, ...  NaN ...   NaN    1
# 13    [Xu, Xibao; Tang, Xuguang] Chinese Acad Sci, N...  NaN ...   NaN    0
# 14    [Lammel, Gerhard; Vrana, Branislav; Efstathiou...  NaN ...   NaN    4
# 15    [Acton, W. Joe F.; Valach, Amy; Hewitt, C. Nic...  NaN ...   NaN    1
# 16    [Schallhart, Simon; Rantala, Pekka; Taipale, D...  NaN ...   NaN    4
# 17    [Hunt, John E.; Laubach, Johannes; Barthel, Ma...  NaN ...   NaN    8
# 18    [Felber, Raphael; Bretscher, Daniel; Neftel, A...  NaN ...   NaN    3
# 19    [Franz, Daniela; Koebsch, Franziska; Larmanou,...  NaN ...   NaN    1
# 20    [Fu, Congsheng; Wang, Guiling] Univ Connecticu...  NaN ...   NaN    0
# 21    [Gorres, Carolyn-Monika; Ceulemans, Reinhart] ...  NaN ...   NaN    1
# 22    [Cassidy, Alison E.; Christen, Andreas; Henry,...  NaN ...   NaN    1
# 23    [Wilkinson, Matthew; Eaton, Edward L.; Morison...  NaN ...   NaN    0
# 24    [Moore, Caitlin E.; Beringer, Jason; McHugh, I...  NaN ...   NaN    6
# 25    [Satar, Ece; Berhanu, Tesfaye A.; Leuenberger,...  NaN ...   NaN    1
# 26    [van der Molen, M. K.; van der Velde, I. R.; K...  NaN ...   NaN    1
# 27    [Hoffmann, H.; Nieto, H.; Jensen, R.; Guzinski...  NaN ...   NaN    5
# 28    [Michel, D.; Hirschi, M.; Seneviratne, S. I.] ...  NaN ...   NaN    9
# 29    [Miralles, D. G.; Dolman, A. J.] Vrije Univ Am...  NaN ...   NaN   10
# ...                                                 ...  ... ...   ...  ...
# 5624  INRA,BIOCLIMATOL STN,F-78850 THIVERVAL GRIGNON...  NaN ...   NaN   24
# 5625  UNIV BRITISH COLUMBIA, DEPT SOIL SCI, VANCOUVE...  NaN ...   NaN   30
# 5626                                                NaN  NaN ...   NaN   59
# 5627  UNIV LEIPZIG,FACHBEREICH PHYS,INST METEOROL,D-...  NaN ...   NaN   20
# 5628  MANAAKI WHENUA LANDCARE RES,CHRISTCHURCH,NEW Z...  NaN ...   NaN   26
# 5629                                                NaN  NaN ...   NaN  423
# 5630                                                NaN  NaN ...   NaN   11
# 5631                                                NaN  NaN ...   NaN    7
# 5632  CTR LAND & BIOL RESOURCES RES,OTTAWA,ON,CANADA...  NaN ...   NaN   12
# 5633  CALIF AIR RESOURCES BOARD, SACRAMENTO, CA USA....  NaN ...   NaN   52
# 5634                                                NaN  NaN ...   NaN   36
# 5635                                                NaN  NaN ...   NaN   18
# 5636                                                NaN  NaN ...   NaN    4
# 5637                                                NaN  NaN ...   NaN    2
# 5638  UNIV BRITISH COLUMBIA,DEPT GEOG,ATMOSPHER SCI ...  NaN ...   NaN   61
# 5639                                                NaN  NaN ...   NaN   32
# 5640                                                NaN  NaN ...   NaN   11
# 5641  UNIV BAYREUTH,LEHRSTUHL PFLANZENOKOL,W-8580 BA...  NaN ...   NaN  121
# 5642  UNIV GUELPH,DEPT LAND RESOURCE SCI,GUELPH N1G ...  NaN ...   NaN   82
# 5643                                                NaN  NaN ...   NaN  414
# 5644                                                NaN  NaN ...   NaN   11
# 5645  UNIV CAPE TOWN, DEPT OCEANOG, RONDEBOSCH 7700,...  NaN ...   NaN   28
# 5646                                                NaN  NaN ...   NaN  262
# 5647  OREGON STATE UNIV,COLL OCEANOG,CORVALLIS,OR 97...  NaN ...   NaN   12
# 5648                                                NaN  NaN ...   NaN   13
# 5649  TELESPAZIO SPA,DIV EARTH OBSERVAT,I-00156 ROME...  NaN ...   NaN   11
# 5650     LAB SYLVICULTURE & ECOL,F-33610 CESTAS,FRANCE.  NaN ...   NaN   65
# 5651  UNIV EDINBURGH,DEPT FORESTRY & NAT RESOURCES,E...  NaN ...   NaN  169
# 5652                                                NaN  NaN ...   NaN  136
# 5653                                                NaN  NaN ...   NaN   53
#
#                                                      TI  U1  U2  \
# 0     Estimation of net surface radiation using eddy...   1   1
# 1     Spatially resolved flux measurements of NOx fr...   8  10
# 2     Ecological controls on N2O emission in surface...  11  12
# 3     Water scarcity and oil palm expansion: social ...  16  28
# 4     Ecohydrological effects of stream-aquifer wate...  10  15
# 5     Evapotranspiration Trend and Its Relationship ...   8   8
# 6     The lifetime of nitrogen oxides in an isoprene...  16  26
# 7     Understanding isoprene photooxidation using ob...   7  10
# 8     Anthropogenic and biogenic influence on VOC fl...   3  12
# 9     Application of an online ion-chromatography-ba...   4  10
# 10    Exploring the potential of the RPA system SUMO...   0   0
# 11    Two years with extreme and little snowfall: ef...   3  10
# 12    Spatial and temporal variations in plant water...   9  12
# 13    REMOTE ESTIMATION OF ECOSYSTEM WATER-USE EFFIC...   1   1
# 14    Bidirectional air-sea exchange and accumulatio...  15  21
# 15    Canopy-scale flux measurements and bottom-up e...   2   8
# 16    Characterization of total ecosystem-scale biog...   2   7
# 17    Carbon budgets for an irrigated intensively gr...   3   6
# 18    Determination of the carbon budget of a pastur...   4   9
# 19    High net CO2 and CH4 release at a eutrophic sh...  10  22
# 20    Combined measurement and modeling of the hydro...   6  12
# 21    Automation of soil flux chamber measurements: ...  15  28
# 22    The effect of a permafrost disturbance on grow...   4   5
# 23    Effects of management thinning on CO2 exchange...  10  15
# 24    The contribution of trees and grasses to produ...   9  18
# 25    Continuous CO2/CH4/CO measurements (2012-2014)...   3  13
# 26    The effect of assimilating satellite-derived s...   7  11
# 27    Estimating evaporation with thermal UAV data a...   6  13
# 28    The WACMOS-ET project - Part 1: Tower-scale ev...  10  15
# 29    The WACMOS-ET project - Part 2: Evaluation of ...  14  22
# ...                                                 ...  ..  ..
# 5624  DOWNWIND EVOLUTION OF SCALAR FLUXES AND SURFAC...   1   2
# 5625  RELATING EDDY-CORRELATION SENSIBLE HEAT-FLUX T...   1   2
# 5626  MEASUREMENTS OF N2O FLUXES FROM FERTILIZED GRA...   0   8
# 5627  APPLICATION OF A SPECTRAL CORRECTION METHOD FO...   0   0
# 5628  SEASONAL PARTITIONING OF EVAPORATION BETWEEN T...   0   1
# 5629    THE LIFE-CYCLE OF THE MADDEN-JULIAN OSCILLATION   5  34
# 5630   A GENERALIZED SCALING FOR CONVECTIVE SHEAR FLOWS   0   2
# 5631        THE FORMATION OF HURRICANE-FREDERIC OF 1979   0   3
# 5632  STRUCTURAL-ANALYSIS OF AIRBORNE FLUX ESTIMATES...   0   1
# 5633  AN EVALUATION OF THE REGIONAL ACID DEPOSITION ...   0   5
# 5634  THE INFLUENCE OF COHERENT STRUCTURES AND MICRO...   0   3
# 5635  TOWARD PARAMETERIZATION OF THE EDDY FIELD NEAR...   0   0
# 5636  SATELLITE ALTIMETRIC DETECTION OF SOMALI EDDIE...   0   1
# 5637  A NOVEL OZONE SENSOR WITH VARIOUS ENVIRONMENTA...   0   0
# 5638  TURBULENT TRANSFER RELATIONSHIPS OVER AN URBAN...   2  11
# 5639  PARTITIONING OZONE FLUXES TO SPARSE GRASS AND ...   0   4
# 5640  A 3-DIMENSIONAL MODEL FOR CALCULATING THE CONC...   0   0
# 5641  EVAPORATION, XYLEM SAP FLOW, AND TREE TRANSPIR...   5  37
# 5642  COMPARISON OF EDDY-COVARIANCE MEASUREMENTS OF ...   1  14
# 5643  OCEAN GENERAL-CIRCULATION FROM A GLOBAL EDDY-R...   7  38
# 5644  MODELING OF ISOTROPIC REACTING TURBULENCE BY A...   0   1
# 5645  CONTRASTING METEOROLOGICAL STRUCTURE OF INTRA-...   0   1
# 5646            STORM TRACKS IN THE SOUTHERN-HEMISPHERE   5  22
# 5647  OCEAN DATA ASSIMILATION USING OPTIMAL INTERPOL...   0   2
# 5648  SEASONAL-VARIATIONS OF SURFACE DYNAMIC TOPOGRA...   0   1
# 5649     AN OBJECTIVE ANALYSIS SCHEME FOR AVHRR IMAGERY   0   1
# 5650  COMPARISON OF 2 METHODS FOR ESTIMATING THE EVA...   2  16
# 5651  EDDY-COVARIANCE CO2 FLUX MEASUREMENTS USING OP...   2  13
# 5652  A GENERAL-CIRCULATION MODEL STUDY OF THE ATMOS...   0   1
# 5653  EFFECTS OF HEAT AND WATER-VAPOR TRANSPORT ON E...   4  15
#
#                        UT   VL   VR  \
# 0     WOS:000381162400001   33  1.0
# 1     WOS:000380099700022  189  NaN
# 2     WOS:000379427700003   13  NaN
# 3     WOS:000380049100006   21  NaN
# 4     WOS:000379419500013   20  NaN
# 5     WOS:000379433600001  NaN  NaN
# 6     WOS:000379417300009   16  NaN
# 7     WOS:000379417300016   16  NaN
# 8     WOS:000379417300032   16  NaN
# 9     WOS:000379397100008    9  NaN
# 10    WOS:000379397100015    9  NaN
# 11    WOS:000379422700003   10  NaN
# 12    WOS:000379425700014    7  NaN
# 13    WOS:000378967600011   25  NaN
# 14    WOS:000378354100021   16  NaN
# 15    WOS:000378354600030   16  NaN
# 16    WOS:000378354600031   16  NaN
# 17    WOS:000378354900005   13  NaN
# 18    WOS:000378354900007   13  NaN
# 19    WOS:000378354900013   13  NaN
# 20    WOS:000377862900021   20  NaN
# 21    WOS:000377274100014   13  NaN
# 22    WOS:000377276700005   13  NaN
# 23    WOS:000377276700010   13  NaN
# 24    WOS:000377276700012   13  NaN
# 25    WOS:000377277300001   13  NaN
# 26    WOS:000377697600002   20  NaN
# 27    WOS:000377697600009   20  NaN
# 28    WOS:000377697600015   20  NaN
# 29    WOS:000377697600016   20  NaN
# ...                   ...  ...  ...
# 5624  WOS:A1994PP63600002   71  NaN
# 5625  WOS:A1994PH35700004   99  NaN
# 5626  WOS:A1994PC94400018   99  NaN
# 5627  WOS:A1994PE93900004   70  NaN
# 5628  WOS:A1994PB91400011   31  NaN
# 5629  WOS:A1994NZ46100004   51  NaN
# 5630  WOS:A1994PD04200004   70  NaN
# 5631  WOS:A1994NQ15600003  122  NaN
# 5632  WOS:A1994NL46500002    7  NaN
# 5633  WOS:A1994NH26300020   99  NaN
# 5634  WOS:A1994MZ16300010  260  NaN
# 5635  WOS:A1993MP73300017   40  NaN
# 5636  WOS:A1993MA24400006   22  NaN
# 5637  WOS:A1993MC24800002  103  NaN
# 5638  WOS:A1993LV83100010  119  NaN
# 5639  WOS:A1993KP20600006   27  NaN
# 5640  WOS:A1993KH51700014   62  NaN
# 5641  WOS:A1992KC98500004   62  NaN
# 5642  WOS:A1992HV73400007   59  NaN
# 5643  WOS:A1992HQ25600024   97  NaN
# 5644  WOS:A1992HP46900006   38  NaN
# 5645  WOS:A1992HJ79700004   12  NaN
# 5646  WOS:A1991GQ81100004   48  NaN
# 5647  WOS:A1991GB33700026   96  NaN
# 5648  WOS:A1991FY14300001   49  NaN
# 5649  WOS:A1991FD71600003   12  NaN
# 5650  WOS:A1991FH04300003   54  NaN
# 5651  WOS:A1990EE37800006   53  NaN
# 5652  WOS:A1990FC72000003    3  NaN
# 5653  WOS:A1982PC59700007   23  NaN
#
#                                                      WC   Z9
# 0                             Geochemistry & Geophysics    0
# 1                                   Chemistry, Physical    3
# 2               Ecology; Geosciences, Multidisciplinary    0
# 3                        Ecology; Environmental Studies    2
# 4       Geosciences, Multidisciplinary; Water Resources    3
# 5                    Meteorology & Atmospheric Sciences    0
# 6                    Meteorology & Atmospheric Sciences    2
# 7                    Meteorology & Atmospheric Sciences    3
# 8                    Meteorology & Atmospheric Sciences    0
# 9                    Meteorology & Atmospheric Sciences    0
# 10                   Meteorology & Atmospheric Sciences    2
# 11    Geography, Physical; Geosciences, Multidiscipl...    3
# 12                       Geosciences, Multidisciplinary    1
# 13                               Environmental Sciences    0
# 14                   Meteorology & Atmospheric Sciences    4
# 15                   Meteorology & Atmospheric Sciences    1
# 16                   Meteorology & Atmospheric Sciences    4
# 17              Ecology; Geosciences, Multidisciplinary    8
# 18              Ecology; Geosciences, Multidisciplinary    3
# 19              Ecology; Geosciences, Multidisciplinary    1
# 20      Geosciences, Multidisciplinary; Water Resources    0
# 21              Ecology; Geosciences, Multidisciplinary    1
# 22              Ecology; Geosciences, Multidisciplinary    1
# 23              Ecology; Geosciences, Multidisciplinary    0
# 24              Ecology; Geosciences, Multidisciplinary    6
# 25              Ecology; Geosciences, Multidisciplinary    1
# 26      Geosciences, Multidisciplinary; Water Resources    1
# 27      Geosciences, Multidisciplinary; Water Resources    5
# 28      Geosciences, Multidisciplinary; Water Resources    9
# 29      Geosciences, Multidisciplinary; Water Resources   10
# ...                                                 ...  ...
# 5624  Agronomy; Forestry; Meteorology & Atmospheric ...   24
# 5625                 Meteorology & Atmospheric Sciences   30
# 5626                 Meteorology & Atmospheric Sciences   60
# 5627                 Meteorology & Atmospheric Sciences   21
# 5628                 Biodiversity Conservation; Ecology   26
# 5629                 Meteorology & Atmospheric Sciences  428
# 5630                 Meteorology & Atmospheric Sciences   11
# 5631                 Meteorology & Atmospheric Sciences    7
# 5632                 Meteorology & Atmospheric Sciences   12
# 5633                 Meteorology & Atmospheric Sciences   55
# 5634               Mechanics; Physics, Fluids & Plasmas   36
# 5635                                       Oceanography   18
# 5636                                       Oceanography    4
# 5637  Engineering, Multidisciplinary; Instruments & ...    2
# 5638                 Meteorology & Atmospheric Sciences   71
# 5639  Environmental Sciences; Meteorology & Atmosphe...   32
# 5640                 Meteorology & Atmospheric Sciences   11
# 5641  Agronomy; Forestry; Meteorology & Atmospheric ...  126
# 5642                 Meteorology & Atmospheric Sciences   90
# 5643                                       Oceanography  422
# 5644                              Engineering, Chemical   11
# 5645                 Meteorology & Atmospheric Sciences   28
# 5646                 Meteorology & Atmospheric Sciences  268
# 5647                                       Oceanography   12
# 5648                                       Oceanography   13
# 5649  Remote Sensing; Imaging Science & Photographic...   11
# 5650  Agronomy; Forestry; Meteorology & Atmospheric ...   71
# 5651                 Meteorology & Atmospheric Sciences  176
# 5652                 Meteorology & Atmospheric Sciences  143
# 5653                 Meteorology & Atmospheric Sciences   56
#
# [5654 rows x 62 columns]

# %% [markdown]
# The data is quite neat and clean here. Each record represents a single paper, Our goal is creating profile for each author, the data should be transformed into Author -> Papers type.
#
# ### 3. Web of Science data transformation
# First, let's check how many papers we have over here.

# %%
len(PRecords)
# Out:
# 5654

# %% [markdown]
# Then each author in each paper is extracted into a single Author data stucture, sorted by primary key FP and subkey SP,waiting for further combination.Meanwhile, we'll target those authors who are Reprint Authors or First Authors.

# %%
#ReGroup the name
PRecords.AF = [names.split('|') for names in PRecords.AF]
PRecords.AU = [names.split('|') for names in PRecords.AU]

#Author Initilization
PreAuthors = []
for index, paper in PRecords.iterrows():
    #Reprint Author Tag
    if  paper.RP == paper.RP:
        Reprint = paper.RP.split(' (re')[0]
        for j, Sname in enumerate(paper.AU):
            if Reprint in Sname:
                PRecords.AF[index][j] += '*'
    #First Author Tag
    PRecords.AF[index][0] += '$'
    
    for name in paper.AF:
        Rptag = 0
        Fstag = 0
        if '*' in name:
            Rptag = 1
        if '$' in name:
            Fstag = 1
        #Append Authors
        PreAuthors.append(Author(Name = NameSequence(str(name)), Paper = paper.DI, POI = index, isReprint = Rptag, isFirst = Fstag))

# %%
PreAuthors[0].PrintName()
print(PreAuthors[0].isReprint, PreAuthors[0].isFirst)
# Out:
# ('Mahalakshmi', 'D', 'V')
# ([1], [1])

# %% [markdown]
# Finally, we'll combine all PreAuthors records according to their name, making profiles for every single author. The name compare algorithm is basically based on similarity check, the similiarity is quantified by weighted Levenshtein distance, and deployed by dif.SequenceMatcher().ratio() function, which is quite time consuming.
# The similarities between some names are confusing for algorithms, so mannual check is inserted to provide help. This internal result will be saved in csv.

# %%
#Double Sort the Preauthor list in Alphabet order, which makes continous calculation more efficient
PreAuthors = sorted(PreAuthors, key = lambda author: author.Name[0].SP)
PreAuthors = sorted(PreAuthors, key = lambda author: author.Name[0].FP)

def Get_Match(x,y): #Inner WoS Name check needs accuracy, so we use .ratio function
    return dif.SequenceMatcher(None,x,y).ratio()

def CheckWOS(x,y): #x and y variables are NameSequence Class
    tag = 0
    CisFP = Get_Match(x.FP.lower(),y.FP.lower())
    CisSP = Get_Match(x.SP.lower(),y.SP.lower())

    if ((CisFP < 0.9 and CisSP < 0.9) or (x.SP[0] != y.SP[0])):
        tag = 0
    elif (CisFP == 1 and CisSP == 1):
        tag = 3
    elif (CisFP >= 0.9 and CisSP >= 0.9):
        tag = 1
    return tag

def MannualCheck(namelist, insertname):
    print('^^^^^^^Please Check^^^^^^^')
    for name in namelist:
        name.Printout()
    print('^^^^^^^^^^^^^^^^^^^^^^^^^^')
    for name in insertname:
        name.Printout()
    tg = input('Match or Not?\n')
    return(tg)

#Initialization of name compare
Authors = []
processed = 0
bias = 0
tag = 0
for pauthor in PreAuthors:
    for i,author in enumerate(Authors[-bias:]):
        #Tag Calculate
        tag = 0
        for j,name in enumerate(author.Name):
              tag = max(tag,CheckWOS(pauthor.Name[0],name))

        #Tag Check
        if tag == 1:
            if MannualCheck(author.Name,pauthor.Name):
                author.Attach(pauthor)
                break
        elif tag == 3:
            author.Attach(pauthor)
            author.Multiname -= 1
            break
    #In case none available names in Authors List            
    if tag == 0: 
        Authors.append(pauthor)
    #Set Check bias to 50 to accelerate the calculation
    bias = min(len(Authors),50)
    processed += 1
    print(processed,tag)
    
#Rebuild Authors to DataFrame and Print to csv
def CombineNameSequence(ns): #Turn NameSequence structure into strings for comparison
    return(ns.FP + ' ' + ns.SP + ' ' + ns.MD)

OutputAuthors = []
for index, author in enumerate(Authors):
    for j, item in enumerate(author.Name):
        OutputAuthors.append({'Universal_Name_Tag':index, 'Name':CombineNameSequence(item), 'Short':author.Short[j], 'Paper':author.Paper[j], 'POI':author.POI[j], 'isReprint':author.isReprint[j], 'isFirst':author.isFirst[j]})

OutputAuthors = pd.DataFrame.from_dict(OutputAuthors)
OutputAuthors.to_csv('D:/_Research/Project_Sharing_Data_FromLinux/ProjectRebuild_2017/Data/FirstStep_Author_Records.csv')
# Out:
# (1, 0)
# (2, 0)
# (3, 0)
# (4, 3)
# (5, 3)
# (6, 3)
# (7, 3)
# (8, 3)
# (9, 0)
# (10, 0)
# (11, 3)
# (12, 3)
# (13, 3)
# (14, 3)
# (15, 0)
# (16, 3)
# (17, 3)
# (18, 3)
# (19, 3)
# (20, 3)
# (21, 3)
# (22, 0)
# (23, 0)
# (24, 0)
# (25, 0)
# (26, 3)
# (27, 0)
# (28, 0)
# (29, 0)
# (30, 0)
# (31, 0)
# (32, 0)
# (33, 0)
# (34, 3)
# (35, 0)
# (36, 0)
# (37, 0)
# (38, 0)
# (39, 3)
# (40, 0)
# (41, 3)
# (42, 0)
# (43, 0)
# (44, 3)
# (45, 0)
# (46, 3)
# (47, 0)
# (48, 0)
# (49, 3)
# (50, 0)
# (51, 3)
# (52, 0)
# (53, 0)
# (54, 3)
# (55, 0)
# (56, 3)
# (57, 0)
# (58, 0)
# (59, 0)
# (60, 0)
# (61, 3)
# (62, 0)
# (63, 3)
# (64, 0)
# (65, 0)
# (66, 3)
# (67, 0)
# (68, 3)
# (69, 3)
# (70, 3)
# (71, 3)
# (72, 3)
# (73, 3)
# (74, 3)
# (75, 0)
# (76, 3)
# (77, 0)
# (78, 0)
# (79, 0)
# (80, 0)
# (81, 0)
# (82, 0)
# (83, 0)
# (84, 0)
# (85, 0)
# (86, 0)
# (87, 3)
# (88, 3)
# (89, 3)
# (90, 0)
# (91, 3)
# (92, 0)
# (93, 0)
# (94, 0)
# (95, 0)
# (96, 0)
# (97, 0)
# (98, 0)
# (99, 0)
# (100, 0)
# (101, 0)
# (102, 0)
# (103, 3)
# (104, 0)
# (105, 3)
# (106, 0)
# (107, 0)
# (108, 0)
# (109, 3)
# (110, 3)
# (111, 3)
# (112, 3)
# (113, 0)
# (114, 3)
# (115, 3)
# (116, 0)
# (117, 0)
# (118, 3)
# (119, 3)
# (120, 0)
# (121, 0)
# (122, 0)
# (123, 0)
# (124, 3)
# (125, 3)
# (126, 0)
# (127, 0)
# (128, 0)
# (129, 3)
# (130, 0)
# (131, 3)
# (132, 3)
# (133, 0)
# (134, 0)
# (135, 0)
# (136, 3)
# (137, 3)
# (138, 3)
# (139, 0)
# (140, 3)
# (141, 3)
# (142, 3)
# (143, 3)
# (144, 3)
# (145, 3)
# (146, 3)
# (147, 0)
# (148, 0)
# ^^^^^^^Please Check^^^^^^^
# ('Ahlstroem', 'Anders', '')
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
# ('Ahlstrom', 'Anders', '')
# (149, 1)
# (150, 0)
# (151, 0)
# (152, 0)
# (153, 0)
# (154, 0)
# (155, 0)
# (156, 0)
# (157, 0)
# (158, 0)
# (159, 0)
# (160, 0)
# (161, 3)
# (162, 3)
# (163, 0)
# (164, 0)
# (165, 0)
# (166, 0)
# (167, 3)
# (168, 3)
# (169, 3)
# (170, 3)
# (171, 0)
# (172, 3)
# (173, 3)
# (174, 3)
# (175, 0)
# (176, 0)
# (177, 0)
# (178, 0)
# (179, 0)
# (180, 0)
# (181, 0)
# (182, 0)
# (183, 0)
# (184, 0)
# (185, 0)
# (186, 0)
# (187, 0)
# (188, 0)
# (189, 0)
# (190, 3)
# (191, 3)
# (192, 3)
# (193, 0)
# (194, 3)
# (195, 0)
# (196, 0)
# (197, 0)
# (198, 0)
# (199, 3)
# (200, 0)
# (201, 0)
# (202, 0)
# (203, 0)
# (204, 0)
# (205, 3)
# (206, 3)
# (207, 3)
# (208, 0)
# (209, 3)
# (210, 3)
# (211, 3)
# (212, 3)
# (213, 3)
# (214, 0)
# (215, 3)
# (216, 3)
# (217, 3)
# (218, 3)
# (219, 3)
# (220, 0)
# (221, 0)
# (222, 3)
# (223, 3)
# (224, 0)
# (225, 3)
# (226, 3)
# (227, 0)
# (228, 3)
# (229, 3)
# (230, 3)
# (231, 0)
# (232, 0)
# (233, 0)
# (234, 0)
# (235, 0)
# (236, 3)
# (237, 0)
# (238, 0)
# (239, 0)
# (240, 3)
# (241, 0)
# (242, 3)
# (243, 3)
# (244, 0)
# (245, 0)
# (246, 0)
# (247, 3)
# (248, 3)
# (249, 0)
# (250, 0)
# (251, 3)
# (252, 0)
# (253, 3)
# (254, 3)
# (255, 3)
# (256, 3)
# (257, 3)
# (258, 3)
# (259, 3)
# (260, 3)
# (261, 3)
# (262, 3)
# (263, 3)
# (264, 3)
# (265, 3)
# (266, 3)
# (267, 0)
# (268, 0)
# (269, 0)
# (270, 0)
# (271, 0)
# (272, 0)
# (273, 0)
# (274, 0)
# (275, 0)
# (276, 3)
# (277, 3)
# (278, 3)
# (279, 3)
# (280, 3)
# (281, 0)
# (282, 0)
# (283, 0)
# (284, 0)
# (285, 0)
# (286, 0)
# (287, 3)
# (288, 0)
# (289, 0)
# (290, 3)
# (291, 0)
# (292, 0)
# (293, 0)
# (294, 3)
# (295, 3)
# (296, 3)
# (297, 0)
# (298, 3)
# (299, 0)
# (300, 0)
# (301, 0)
# (302, 0)
# (303, 0)
# (304, 0)
# (305, 0)
# (306, 0)
# (307, 0)
# (308, 0)
# (309, 3)
# (310, 3)
# (311, 3)
# (312, 0)
# (313, 3)
# (314, 3)
# (315, 3)
# (316, 3)
# (317, 3)
# (318, 0)
# (319, 0)
# (320, 3)
# (321, 3)
# (322, 3)
# (323, 3)
# (324, 3)
# (325, 3)
# (326, 0)
# (327, 0)
# (328, 0)
# (329, 0)
# (330, 0)
# (331, 3)
# (332, 0)
# (333, 0)
# (334, 0)
# (335, 0)
# (336, 3)
# (337, 0)
# (338, 0)
# (339, 0)
# (340, 0)
# (341, 0)
# (342, 3)
# (343, 3)
# (344, 3)
# (345, 3)
# (346, 3)
# (347, 0)
# (348, 3)
# (349, 3)
# (350, 3)
# (351, 3)
# (352, 3)
# (353, 0)
# (354, 0)
# (355, 0)
# (356, 3)
# (357, 0)
# (358, 3)
# (359, 0)
# (360, 0)
# (361, 3)
# (362, 3)
# (363, 3)
# (364, 3)
# (365, 3)
# (366, 3)
# (367, 3)
# (368, 3)
# (369, 0)
# (370, 3)
# (371, 3)
# (372, 0)
# (373, 3)
# (374, 3)
# (375, 3)
# (376, 3)
# (377, 3)
# (378, 3)
# (379, 3)
# (380, 3)
# (381, 3)
# (382, 3)
# (383, 3)
# (384, 0)
# ^^^^^^^Please Check^^^^^^^
# ('Amman', 'C', '')
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
# ('Ammann', 'C', '')

# %% [markdown]
# This step may cost quite a long time (both automatical and mannual work), but if we check the data again, we'll find some more names to be combine with.
# So a second automatically name check will be performed to combine neighbor similiar names, this check is mostly based on Short Name check. Neighbour names with same Short Name will be combined.

# %%
#Second Check on Short Names
def Picklongest(ShortName):
    temp = ''
    for sn in ShortName:
        secondpart = sn.split(', ')[1]
        if len(secondpart) > len(temp):
            temp = secondpart
    return(temp)

Authors = sorted(Authors, key = lambda author: author.Short[0])
RAuthors = []
for index, author in enumerate(Authors):
    if index == 0:
        RAuthors.append(author)
    else:
        prvS = Picklongest(RAuthors[-1].Short)
        crtS = Picklongest(Authors[index].Short)

        if (prvS in crtS) or (crtS in prvS):
            tag = 1
        else:
            tag = 0
           
        if tag:
            RAuthors[-1].Attach(Authors[index])
        else:
            RAuthors.append(author)

# %% [markdown]
# After this combination, we shall just output the result to local disk for fast reload in future work.

# %%
##Direct Output Authors
Fileoutput = open('D:/_Research/Project_Sharing_Data_FromLinux/ProjectRebuild_2017/Data/UnifieAuthors.txt','w')
for author in RAuthors:
    #Print names
    for name in author.Name:
        ft = name.FP + '$' + name.SP + '$' + name.MD + '@'
        print >> Fileoutput, ft,
    print >> Fileoutput
    #Print PaperDOI
    for paper in author.Paper:  
        if paper != paper:
            print >> Fileoutput, '|',
        else:
            print >> Fileoutput, paper + '|',
    print >> Fileoutput
    #Print POI
    for poi in author.POI:
        print >> Fileoutput, str(poi) + '|',
    print >> Fileoutput
    #Print isRePrint
    for rpt in author.isReprint:
        print >> Fileoutput, str(rpt) + '|',
    print >> Fileoutput   
    #Print isFirst
    for fst in author.isFirst:
        print >> Fileoutput, str(fst) + '|',
    print >> Fileoutput
Fileoutput.close()

# %% [markdown]
# It's better to save this dataset in a DataFrame of pandas, transform the RAuthor data to dict and further pd.DataFrame.
# We'll also attach the unifield authors to previous record table, then save the result to disk.

# %%
#Rebuild Authors to DataFrame and Print to csv
def CombineNameSequence(ns): #Turn NameSequence structure into strings for comparison
    return(ns.FP + ' ' + ns.SP + ' ' + ns.MD)
Authors = []

for index, author in enumerate(RAuthors):
    for j, item in enumerate(author.Name):
        Authors.append({'Universal_Name_Tag':index, 'Name':CombineNameSequence(item), 'Paper':author.Paper[j], 'POI':author.POI[j], 'isReprint':author.isReprint[j], 'isFirst':author.isFirst[j]})

Authors = pd.DataFrame.from_dict(Authors)
Authors.to_csv('D:/_Research/Project_Sharing_Data_FromLinux/ProjectRebuild_2017/Data/Full_Author_Records.csv')

# %%
#Attach Unifield Key to the table
Pcords = ['' for cols in range(len(PRecords))]
#Remark the Author by UniqueNumbers
for index, author in enumerate(RAuthors):
    print(index)
    for Pnum in author.POI:
        Pcords[int(Pnum)] += str(index) + '|'
PRecords['Author_Unique_Key'] = Pcords

import sys
reload(sys)
sys.setdefaultencoding('utf-8')
PRecords.to_csv('D:/_Research/Project_Sharing_Data_FromLinux/ProjectRebuild_2017/Data/Full_Record_With_AuthorKey.csv')

# %% [markdown]
# ### 4. Reload author and investigator data
# Load processed investigator data into a new class Investor. For investigator data was crawled form the ineternet, we should first remove all punctuations inside investor name fields. We don't want to deduplciate WoS a second time, so we just reload the author data saved in the last section.

# %%
from string import punctuation
import difflib as dif

Fileinput = open('D:/_Research/Project_Sharing_Data_FromLinux/ProjectRebuild_2017/Data/SiteInfo/InvestSite.txt')
Investors = []
for lines in Fileinput:
    temp = lines.replace('\n','').split('|')
    Investors.append(Investor(temp[0].translate(None,punctuation),temp[1].split(',')))
Fileinput.close()

Authors = pd.read_csv('D:/_Research/Project_Sharing_Data_FromLinux/ProjectRebuild_2017/Data/Universal_Author_Scores.csv')
Authors = Authors.drop('Unnamed: 0', axis = 1)
Authors
# Out:
#       Citation_Score                    NameIndex  \
# 0           2.000000                   ARCADO TE
# 1           1.000000                  Aalto Juho
# 2          31.529762                    Aalto P P
# 3          34.042857                 Aalto Tuula
# 4           2.833333                  Abaimov A P
# 5           0.101695                    Abaoui J
# 6           0.000000             Abdalati Waleed
# 7           5.581395             Abdalla Mohamed
# 8           0.000000          Abdalla Seifeldin H
# 9           6.000000        Abdelghani Chehbouni
# 10          0.000000             Abdelrady Ahmed
# 11          1.000000             AbdulAziz Omar I
# 12          7.250000                       Abe S
# 13        147.522344                  Aber John D
# 14          0.935028                  Abourida A
# 15          7.000000              Abraha Michael
# 16          9.202797                Abrahamsen P
# 17          2.350000                  Abramova K
# 18        117.499008              Abramowitz Gab
# 19          1.625000           AbuNaser Mohammad
# 20          9.000000               Abudu Shalamu
# 21          2.538462          Abulaiti Abulitipu
# 22         99.413980         Acevedo Otavio Costa
# 23          0.142857               Acharya Kumud
# 24          0.000000           Achenza Francesca
# 25          0.250000                 Achiman Ori
# 26          0.285714              Achkar Antonio
# 27          0.000000            Achten Christine
# 28         15.846154             Achuatavarier D
# 29          0.222222                 Ackerman A S
# ...              ...                          ...
# 9696        0.000000            van Leth Thomas C
# 9697        1.400000           van Lipzig Nicole
# 9698        2.333333                 van Loon E E
# 9699        3.076923           van Loon Marloes P
# 9700        0.222222                  van Oost K
# 9701        0.500000                van Putten B
# 9702        5.428571               van Putten EM
# 9703        0.636364  van Scheltinga A Terwisscha
# 9704       12.111111                van Zanten M
# 9705       24.732143          van de Boer Anneke
# 9706       12.952824             van den Bulk W C
# 9707        0.000000     van de Weg Martine Janet
# 9708        2.820635          van den Hurk Bart J
# 9709        1.750000  van den Kroonenberg Aline C
# 9710       65.038889          van der Kamp Garth
# 9711        6.384615              van der Keur P
# 9712        4.333333              van der Laan M
# 9713        0.745455         van der Laan Sander
# 9714        0.833333  van der LaanLuijkx Ingrid T
# 9715        1.333333            van der Linden L
# 9716        5.470588    van der Linden Sebastian
# 9717        4.666667            van der Merwe M R
# 9718      236.845418      van der Molen Michiel K
# 9719       45.674603      van der Tol Christiaan
# 9720        0.326923        van der Velde Rogier
# 9721        5.239709             van der Werf G R
# 9722        0.857143         van der Zee Sjoerd E
# 9723        2.222222            von Arnold Karin
# 9724        1.714286                  von Bloh W
# 9725       63.467753       von der Heide Carolin
#
#                                                   Names  \
# 0                                           ARCADO TE |
# 1                                          Aalto Juho |
# 2     Aalto P |Aalto P |Aalto P P|Aalto P |Aalto P |...
# 3     Aalto T |Aalto T |Aalto T |Aalto T |Aalto T |A...
# 4                                          Abaimov A P|
# 5                                            Abaoui J |
# 6                                     Abdalati Waleed |
# 7               Abdalla M |Abdalla M |Abdalla Mohamed |
# 8                                  Abdalla Seifeldin H|
# 9                                Abdelghani Chehbouni |
# 10                                    Abdelrady Ahmed |
# 11                                    AbdulAziz Omar I|
# 12                                              Abe S |
# 13    Aber J |Aber J |Aber JD |Aber John D|Aberg J |...
# 14                             Abourida A |Abourida A |
# 15          Abraha Michael |Abraha Michael |Abraha M G|
# 16                         Abrahamsen P |Abrahamsen P |
# 17                                         Abramova K |
# 18    Abramowitz G |Abramowitz G |Abramowitz Gab |Ab...
# 19                                  AbuNaser Mohammad |
# 20                                      Abudu Shalamu |
# 21     Abulaiti Abulitipu |Ac Alexander |Ac Alexander |
# 22    Acevedo C |Acevedo C |Acevedo O C|Acevedo OC |...
# 23                       Acharya Kumud |Acharya Kumud |
# 24                                  Achenza Francesca |
# 25                                        Achiman Ori |
# 26                                     Achkar Antonio |
# 27                                   Achten Christine |
# 28                                    Achuatavarier D |
# 29                                        Ackerman A S|
# ...                                                 ...
# 9696                                 van Leth Thomas C|
# 9697                                van Lipzig Nicole |
# 9698                                      van Loon E E|
# 9699                   van Loon Marloes P|van Oijen M |
# 9700                                       van Oost K |
# 9701                                     van Putten B |
# 9702                                    van Putten EM |
# 9703                       van Scheltinga A Terwisscha|
# 9704           van Wijk M T|van Wijk MT |van Zanten M |
# 9705  van de Boer A |van de Boer A |van de Boer A |v...
# 9706  van de Bulk W C|van den Bulk W C|van den Bulk ...
# 9707      van de Weg Martine Janet|van den Berg Merit |
# 9708  van den Hurk B |van den Hurk Bart |van den Hur...
# 9709                       van den Kroonenberg Aline C|
# 9710  van der Kamp G |van der Kamp G |van der Kamp G...
# 9711                                   van der Keur P |
# 9712                                   van der Laan M |
# 9713  van der Laan S |van der Laan Sander |van der L...
# 9714  van der LaanLuijkx Ingrid |van der LaanLuijkx ...
# 9715                                 van der Linden L |
# 9716                         van der Linden Sebastian |
# 9717                                 van der Merwe M R|
# 9718  van der Molen Michiel |van der Molen Michiel K...
# 9719  van der Sande CJ |van der Tol C |van der Tol C...
# 9720           van der Velde I R|van der Velde Rogier |
# 9721                  van der Werf G |van der Werf G R|
# 9722                              van der Zee Sjoerd E|
# 9723                                 von Arnold Karin |
# 9724                                       von Bloh W |
# 9725  von Randow C |von Randow C |von Randow C |von ...
#
#                                             Short_Names  Total_Citation  \
# 0                                           ARCADO, TE|              32
# 1                                             Aalto, J|               7
# 2     Aalto, P|Aalto, P|Aalto, PP|Aalto, P|Aalto, P|...             241
# 3     Aalto, T|Aalto, T|Aalto, T|Aalto, T|Aalto, T|A...             171
# 4                                          Abaimov, AP|              17
# 5                                            Abaoui, J|               6
# 6                                          Abdalati, W|               0
# 7                     Abdalla, M|Abdalla, M|Abdalla, M|             156
# 8                                          Abdalla, SH|               0
# 9                                        Abdelghani, C|               6
# 10                                        Abdelrady, A|               0
# 11                                      Abdul-Aziz, OI|               1
# 12                                              Abe, S|              29
# 13    Aber, J|Aber, J|Aber, JD|Aber, JD|Aberg, J|Abe...             842
# 14                             Abourida, A|Abourida, A|              16
# 15                      Abraha, M|Abraha, M|Abraha, MG|               7
# 16                         Abrahamsen, P|Abrahamsen, P|             114
# 17                                         Abramova, K|              47
# 18    Abramowitz, G|Abramowitz, G|Abramowitz, G|Abra...             324
# 19                                        Abu-Naser, M|              13
# 20                                            Abudu, S|               9
# 21                             Abulaiti, A|Ac, A|Ac, A|              33
# 22    Acevedo, C|Acevedo, C|Acevedo, OC|Acevedo, OC|...             252
# 23                               Acharya, K|Acharya, K|               1
# 24                                          Achenza, F|               0
# 25                                          Achiman, O|               1
# 26                                           Achkar, A|               2
# 27                                           Achten, C|               0
# 28                                    Achuatavarier, D|             206
# 29                                        Ackerman, AS|               2
# ...                                                 ...             ...
# 9696                                      van Leth, TC|               0
# 9697                                     van Lipzig, N|               7
# 9698                                      van Loon, EE|              28
# 9699                         van Loon, MP|van Oijen, M|              16
# 9700                                       van Oost, K|               2
# 9701                                     van Putten, B|               2
# 9702                                    van Putten, EM|              38
# 9703                                van Scheltinga, AT|              21
# 9704           van Wijk, MT|van Wijk, MT|van Zanten, M|              69
# 9705  van de Boer, A|van de Boer, A|van de Boer, A|v...              37
# 9706  van de Bulk, WCM|van den Bulk, WCM|van den Bul...             215
# 9707                    van de Weg, MJ|van den Berg, M|               0
# 9708  van den Hurk, B|van den Hurk, B|van den Hurk, ...              51
# 9709                           van den Kroonenberg, AC|              21
# 9710  van der Kamp, G|van der Kamp, G|van der Kamp, ...             148
# 9711                                   van der Keur, P|              83
# 9712                                   van der Laan, M|              39
# 9713   van der Laan, S|van der Laan, S|van der Laan, S|               7
# 9714    van der Laan-Luijkx, I|van der Laan-Luijkx, IT|              10
# 9715                                 van der Linden, L|               8
# 9716                                 van der Linden, S|              93
# 9717                                 van der Merwe, MR|              28
# 9718  van der Molen, M|van der Molen, MK|van der Mol...             647
# 9719  van der Sande, CJ|van der Tol, C|van der Tol, ...             177
# 9720                van der Velde, IR|van der Velde, R|               3
# 9721                  van der Werf, G|van der Werf, GR|             130
# 9722                                van der Zee, SEATM|               6
# 9723                                     von Arnold, K|              20
# 9724                                       von Bloh, W|              12
# 9725  von Randow, C|von Randow, C|von Randow, C|von ...             491
#
#       Total_Publication  LeaderRank
# 0                     1    0.281736
# 1                     1    0.406272
# 2                     7    1.863562
# 3                    12    1.864732
# 4                     1    0.367166
# 5                     1    0.284561
# 6                     1    0.388332
# 7                     3    0.425961
# 8                     1    0.596599
# 9                     1    0.395203
# 10                    1    0.326181
# 11                    1    0.338646
# 12                    1    0.431309
# 13                    7    3.802905
# 14                    2    0.298491
# 15                    3    0.637587
# 16                    2    0.489635
# 17                    1    0.315536
# 18                    8    1.950972
# 19                    1    0.369726
# 20                    1    0.409806
# 21                    3    0.389477
# 22                   13    2.553484
# 23                    2    0.312800
# 24                    1    0.428551
# 25                    1    0.375350
# 26                    1    0.335132
# 27                    1    0.351733
# 28                    1    0.544363
# 29                    1    0.289223
# ...                 ...         ...
# 9696                  1    0.437936
# 9697                  1    0.591557
# 9698                  1    0.383724
# 9699                  2    0.398925
# 9700                  1    0.289702
# 9701                  1    0.935920
# 9702                  1    0.392436
# 9703                  1    0.297994
# 9704                  3    1.233418
# 9705                  6    1.042132
# 9706                  5    0.632364
# 9707                  2    0.352968
# 9708                  3    0.379087
# 9709                  1    0.326455
# 9710                  4    2.102741
# 9711                  1    0.386167
# 9712                  1    0.362385
# 9713                  3    0.389170
# 9714                  2    0.526864
# 9715                  1    0.451322
# 9716                  1    0.361859
# 9717                  1    0.438423
# 9718                 20    5.282731
# 9719                 11    1.569746
# 9720                  2    0.363133
# 9721                  2    0.412352
# 9722                  1    0.362375
# 9723                  1    0.347295
# 9724                  1    0.371948
# 9725                 14    2.190627
#
# [9726 rows x 7 columns]

# %% [markdown]
# ### 5. Combine two datasets
# Now we can combine the Investors into Author datasets by the similarity of names. In this  section, we'll only automatically accept 100% similarity combination, while for those pairs with lower similarities, a mannual check will be conducted to determine the following operation.

# %%
def Get_Quick_Match(x,y): #Name check here is less strict, quick ratio is fine
    return dif.SequenceMatcher(None,x,y).quick_ratio()

def MannualCrossCheck(author, invest):
    print('^^^^^^^Please Check^^^^^^^')
    print(author)
    print('^^^^^^^^^^^^^^^^^^^^^^^^^^')
    print(invest.Name)
    tg = input('Match or Not?\n')
    return(tg)

Sites = [[] for cols in range(len(Authors))]

for num,invest in enumerate(Investors):
    cpvalue = 0
    record = 0
    for i,author in Authors.iterrows():
        temp = 0
        for name in author.Names.replace(' |','|').split('|'):
            temp = max(temp,Get_Quick_Match(invest.Name, name))
        if temp > cpvalue:
            record = i
            cpvalue = temp
            
    if cpvalue > 0.9:
        Sites[record].extend(invest.Sites)
        print(str(num) + ': ' + invest.Name + ' & ' + Authors.NameIndex[record] + '--------' + str(100*cpvalue) + '% Match!')
    elif MannualCrossCheck(Authors.Names[record], invest):
        Sites[record].extend(invest.Sites)
        print(str(num) +  ': ' + invest.Name + ' & ' + Authors.NameIndex[record] + '--------' + str(100*cpvalue) + '% Match!')
    else:
        print(str(num) + ': ' + invest.Name + ' & ' + Authors.NameIndex[record] + '--------' + str(100*cpvalue) + '    Not Match!')

CSites = ['' for cols in range(len(Authors))]
for index, item in enumerate(Sites):
    for sc in item:
        CSites[index] += sc + ','

Authors['Invested_Site'] = CSites
Authors.to_csv('D:/_Research/Project_Sharing_Data_FromLinux/ProjectRebuild_2017/Data/Sites_LeaderRank_AuthorList.csv')
# Out:
# ^^^^^^^Please Check^^^^^^^
# Oishi A Christopher|Oishi A Christopher|Oishi A Christopher|Oishi A Christopher|Oishi A Christopher|Oishi A Christopher|Oishi A Christopher|Oishi AC |Oishi C |Ojala A |Ojala Anne |Ojala Anne |Ojala Anne |Ojala Anne |Ojala Anne |Ojala Anne |Ojala Anne |Ojala Anne |Ojala Anne |
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
# A Chris Oishi
# 0: A Chris Oishi & Oishi A Christopher--------81.25% Match!
# 1: Abad Chabbi & Chabbi Abad --------100.0% Match!
# 2: Abel Rodrigues & Rodrigues Abel --------100.0% Match!
# 3: Achim Grelle & Grelle Achim --------100.0% Match!
# 4: Adam Wolf & Wolf Annett --------100.0% Match!
# 5: Adrian Rocha & Rocha Adrian V--------100.0% Match!
# 6: Aikaterini Trepekli & Trepekli Aikaterini --------100.0% Match!
# 7: Akira Miyata & Miyata Akira --------100.0% Match!
# 8: Alan Barr & Barr Alan G--------100.0% Match!
# ^^^^^^^Please Check^^^^^^^
# Karppinen A |Karsanaev S A|Karsanaev S A|Karsanaev S A|Karsanaev S V|
# ^^^^^^^^^^^^^^^^^^^^^^^^^^
# Alan Knapp
